# %% [markdown]
# <a href="https://www.kaggle.com/code/shubhamgupta012/research-paper-jsonl-to-csv?scriptVersionId=137459072" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/research-paper/dataset.jsonl

# %%
# Set display option to show all columns
pd.set_option('display.max_columns', None)

# %%
# Replace 'your_file.jsonl' with the path to your JSONL file.
df = pd.read_json('/kaggle/input/research-paper/dataset.jsonl', lines=True)
df.head()
# Out:
#      paper_id  _pdf_hash                              _source_hash  \
# 0  2001.00542        NaN  2cf7d91955338de8806cedfaad463edaa03b353e
# 1  2001.00552        NaN  cd9ad8a0cbb2f1bb1a6f67be4b3c7d0e434e58b3
# 2  2001.01128        NaN  2720ef9c27a2fd932d68cc901136ad880b22af32
# 3  2001.01237        NaN  16d4646f55552b42dc8260150707b6ef96ae9070
# 4  2001.01618        NaN  ec6d66a2df60dd2975aab31d10b83a08542f7d45
#
#     _source_name                                           metadata  \
# 0  2001.00542.gz  {'id': '2001.00542', 'submitter': 'Uro\v{s} Tk...
# 1  2001.00552.gz  {'id': '2001.00552', 'submitter': 'Uro\v{s} Tk...
# 2  2001.01128.gz  {'id': '2001.01128', 'submitter': 'Ilan Ben-Ba...
# 3  2001.01237.gz  {'id': '2001.01237', 'submitter': 'Ligong Bian...
# 4  2001.01618.gz  {'id': '2001.01618', 'submitter': 'Sudipta Pau...
#
#    discipline                                           abstract  \
# 0     Physics  {'section': 'Abstract', 'text': '  Compared to...
# 1     Physics  {'section': 'Abstract', 'text': '  Pure liquid...
# 2  Statistics  {'section': 'Abstract', 'text': '  Web applica...
# 3     Physics  {'section': 'Abstract', 'text': '  We study st...
# 4  Statistics  {'section': 'Abstract', 'text': '  Differentia...
#
#                                            body_text  \
# 0  [{'section': '', 'sec_number': '-1', 'sec_type...
# 1  [{'section': '', 'sec_number': '-1', 'sec_type...
# 2  [{'section': 'INTRODUCTION', 'sec_number': '1'...
# 3  [{'section': 'Supplemental material', 'sec_num...
# 4  [{'section': 'Introduction', 'sec_number': '1'...
#
#                                          bib_entries  \
# 0                                                 {}
# 1                                                 {}
# 2  {'fd348bb730364500beec84e6d07f229a9ac881c5': {...
# 3  {'b7617d845bed30eeb2da9879ad21dc34280655c4': {...
# 4  {'ff4a579d4abedc40931f2b06ecbeab82c4489299': {...
#
#                                          ref_entries
# 0  {'336749f9-1c00-42ce-b19d-ccbc2650785b': {'cap...
# 1  {'9e47e1d7-6266-43a5-82de-d13c566b1a83': {'cap...
# 2  {'d81d90e9-cf08-44d2-942c-1bfffe7144a4': {'cap...
# 3  {'eda44882-5b51-4828-9084-b95846977966': {'cap...
# 4  {'cf732af0-acbf-423b-9a8b-0e642579cff1': {'cap...

# %%
df.shape
# Out:
# (795, 10)

# %%
df.dtypes
# Out:
# paper_id        float64
# _pdf_hash       float64
# _source_hash     object
# _source_name     object
# metadata         object
# discipline       object
# abstract         object
# body_text        object
# bib_entries      object
# ref_entries      object
# dtype: object

# %%
df.describe()
# Out:
#           paper_id  _pdf_hash
# count   795.000000        0.0
# mean   1955.636100        NaN
# std      88.574831        NaN
# min    1801.008620        NaN
# 25%    1812.053880        NaN
# 50%    2007.003070        NaN
# 75%    2011.104670        NaN
# max    2012.157640        NaN

# %%
# %time metadata = pd.DataFrame([md for md in df.metadata])
metadata.head()
# Out:
# CPU times: user 6.04 ms, sys: 1.83 ms, total: 7.86 ms
# Wall time: 7.74 ms
#            id         submitter  \
# 0  2001.00542   Uro\v{s} Tkalec
# 1  2001.00552   Uro\v{s} Tkalec
# 2  2001.01128   Ilan Ben-Bassat
# 3  2001.01237       Ligong Bian
# 4  2001.01618  Sudipta Paul Ms.
#
#                                              authors  \
# 0  Simon \v{C}opar, \v{Z}iga Kos, Tadej Emer\v{s}...
# 1  Tadej Emer\v{s}i\v{c}, Rui Zhang, \v{Z}iga Kos...
# 2                     Ilan Ben-Bassat and Erez Rokah
# 3                            Ruiyu Zhou, Ligong Bian
# 4                  Sudipta Paul and Subhankar Mishra
#
#                                                title  \
# 0  Microfluidic control over topological states i...
# 1        Sculpting stable structures in pure liquids
# 2  Locality-Sensitive Hashing for Efficient Web A...
# 3  Gravitational wave and electroweak baryogenesi...
# 4  ARA : Aggregated RAPPOR and Analysis for Centr...
#
#                                     comments  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3  7 pages, 5 figures, PLB published version
# 4                                       None
#
#                                          journal-ref  \
# 0          Nature Communications, vol. 11, 59 (2020)
# 1          Science Advances, vol. 5, eaav4283 (2019)
# 2  In Proceedings of the 5th International Confer...
# 3                      Phys.Lett.B 829 (2022) 137105
# 4                       SN COMPUT. SCI. (2020) 1: 22
#
#                               doi report-no           categories  \
# 0      10.1038/s41467-019-13789-9      None        cond-mat.soft
# 1          10.1126/sciadv.aav4283      None        cond-mat.soft
# 2        10.5220/0007255301930204      None  cs.CR cs.LG stat.ML
# 3  10.1016/j.physletb.2022.137105      None   hep-ph astro-ph.CO
# 4       10.1007/s42979-019-0023-y      None  cs.CR cs.LG stat.ML
#
#                                        license  \
# 0  http://creativecommons.org/licenses/by/4.0/
# 1  http://creativecommons.org/licenses/by/4.0/
# 2  http://creativecommons.org/licenses/by/4.0/
# 3  http://creativecommons.org/licenses/by/4.0/
# 4  http://creativecommons.org/licenses/by/4.0/
#
#                                             abstract  \
# 0    Compared to isotropic liquids, orientational...
# 1    Pure liquids in thermodynamic equilibrium ar...
# 2    Web application security has become a major ...
# 3    We study stochastic gravitational wave produ...
# 4    Differential privacy(DP) has now become a st...
#
#                                             versions update_date  \
# 0  [{'version': 'v1', 'created': 'Thu, 2 Jan 2020...  2020-01-03
# 1  [{'version': 'v1', 'created': 'Thu, 2 Jan 2020...  2020-01-03
# 2  [{'version': 'v1', 'created': 'Sat, 4 Jan 2020...  2020-01-07
# 3  [{'version': 'v1', 'created': 'Sun, 5 Jan 2020...  2022-04-19
# 4  [{'version': 'v1', 'created': 'Mon, 6 Jan 2020...  2020-01-07
#
#                                       authors_parsed
# 0  [[Čopar, Simon, ], [Kos, Žiga, ], [Emeršič, Ta...
# 1  [[Emeršič, Tadej, ], [Zhang, Rui, ], [Kos, Žig...
# 2            [[Ben-Bassat, Ilan, ], [Rokah, Erez, ]]
# 3                [[Zhou, Ruiyu, ], [Bian, Ligong, ]]
# 4         [[Paul, Sudipta, ], [Mishra, Subhankar, ]]

# %%
# %time abstract = pd.DataFrame([md for md in df.abstract])
abstract.head()
# Out:
# CPU times: user 3.47 ms, sys: 0 ns, total: 3.47 ms
# Wall time: 3.41 ms
#     section                                               text cite_spans  \
# 0  Abstract    Compared to isotropic liquids, orientational...         []
# 1  Abstract    Pure liquids in thermodynamic equilibrium ar...         []
# 2  Abstract    Web application security has become a major ...         []
# 3  Abstract    We study stochastic gravitational wave produ...         []
# 4  Abstract    Differential privacy(DP) has now become a st...         []
#
#   ref_spans
# 0        []
# 1        []
# 2        []
# 3        []
# 4        []

# %%
# %time body = pd.DataFrame([md for md in df.body_text])
body.head()
# Out:
# CPU times: user 88.5 ms, sys: 89 µs, total: 88.6 ms
# Wall time: 87.5 ms
#                                                 0     \
# 0  {'section': '', 'sec_number': '-1', 'sec_type'...
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3  {'section': 'Supplemental material', 'sec_numb...
# 4  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                 1     \
# 0  {'section': '', 'sec_number': '-1', 'sec_type'...
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3  {'section': 'Supplemental material', 'sec_numb...
# 4  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                 2     \
# 0  {'section': '', 'sec_number': '-1', 'sec_type'...
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3  {'section': 'Supplemental material', 'sec_numb...
# 4  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                 3     \
# 0  {'section': '', 'sec_number': '-1', 'sec_type'...
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3  {'section': 'Supplemental material', 'sec_numb...
# 4  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                 4     \
# 0  {'section': '', 'sec_number': '-1', 'sec_type'...
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3  {'section': 'Supplemental material', 'sec_numb...
# 4  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                 5     \
# 0  {'section': '', 'sec_number': '-1', 'sec_type'...
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3  {'section': 'Supplemental material', 'sec_numb...
# 4  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                 6     \
# 0  {'section': '', 'sec_number': '-1', 'sec_type'...
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3  {'section': 'Supplemental material', 'sec_numb...
# 4  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                 7     \
# 0  {'section': '', 'sec_number': '-1', 'sec_type'...
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3  {'section': 'Supplemental material', 'sec_numb...
# 4  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                 8     \
# 0  {'section': '', 'sec_number': '-1', 'sec_type'...
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3  {'section': 'Supplemental material', 'sec_numb...
# 4  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                 9     \
# 0  {'section': '', 'sec_number': '-1', 'sec_type'...
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'RELATED WORK', 'sec_number': '2',...
# 3  {'section': 'Supplemental material', 'sec_numb...
# 4  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                 10    \
# 0  {'section': '', 'sec_number': '-1', 'sec_type'...
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'RELATED WORK', 'sec_number': '2',...
# 3                                               None
# 4  {'section': 'Related Work', 'sec_number': '2',...
#
#                                                 11    \
# 0  {'section': '', 'sec_number': '-1', 'sec_type'...
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'RELATED WORK', 'sec_number': '2',...
# 3                                               None
# 4  {'section': 'Related Work', 'sec_number': '2',...
#
#                                                 12    \
# 0                                               None
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'RELATED WORK', 'sec_number': '2',...
# 3                                               None
# 4  {'section': None, 'sec_number': '2.1', 'sec_ty...
#
#                                                 13    \
# 0                                               None
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'RELATED WORK', 'sec_number': '2',...
# 3                                               None
# 4  {'section': None, 'sec_number': '2.1', 'sec_ty...
#
#                                                 14    \
# 0                                               None
# 1  {'section': '', 'sec_number': '-1', 'sec_type'...
# 2  {'section': 'RELATED WORK', 'sec_number': '2',...
# 3                                               None
# 4  {'section': None, 'sec_number': '2.1', 'sec_ty...
#
#                                                 15    \
# 0                                               None
# 1                                               None
# 2  {'section': 'RELATED WORK', 'sec_number': '2',...
# 3                                               None
# 4  {'section': None, 'sec_number': '2.1', 'sec_ty...
#
#                                                 16    \
# 0                                               None
# 1                                               None
# 2  {'section': 'RELATED WORK', 'sec_number': '2',...
# 3                                               None
# 4  {'section': None, 'sec_number': '2.1.1', 'sec_...
#
#                                                 17    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                               None
# 4  {'section': None, 'sec_number': '2.1.2', 'sec_...
#
#                                                 18    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                               None
# 4  {'section': None, 'sec_number': '2.1.2', 'sec_...
#
#                                                 19    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                               None
# 4  {'section': ' ', 'sec_number': '2.2', 'sec_typ...
#
#                                                 20    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                               None
# 4  {'section': ' ', 'sec_number': '2.2', 'sec_typ...
#
#                                                 21    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                               None
# 4  {'section': None, 'sec_number': '3.1', 'sec_ty...
#
#                                                 22    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                               None
# 4  {'section': None, 'sec_number': '3.2', 'sec_ty...
#
#                                                 23    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                               None
# 4  {'section': None, 'sec_number': '3.2', 'sec_ty...
#
#                                                 24    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                               None
# 4  {'section': None, 'sec_number': '3.2', 'sec_ty...
#
#                                                 25    \
# 0                                               None
# 1                                               None
# 2  {'section': 'METHOD', 'sec_number': '4', 'sec_...
# 3                                               None
# 4  {'section': None, 'sec_number': '3.2', 'sec_ty...
#
#                                                 26    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Set Representation of Web Pages',...
# 3                                               None
# 4  {'section': None, 'sec_number': '3.3', 'sec_ty...
#
#                                                 27    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Set Representation of Web Pages',...
# 3                                               None
# 4  {'section': None, 'sec_number': '3.4', 'sec_ty...
#
#                                                 28    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Set Representation of Web Pages',...
# 3                                               None
# 4  {'section': None, 'sec_number': '3.4', 'sec_ty...
#
#                                                 29    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Efficient LSH for MinHash Sketche...
# 3                                               None
# 4  {'section': None, 'sec_number': '3.4', 'sec_ty...
#
#                                                 30    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Efficient LSH for MinHash Sketche...
# 3                                               None
# 4  {'section': None, 'sec_number': '3.5', 'sec_ty...
#
#                                                 31    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Efficient LSH for MinHash Sketche...
# 3                                               None
# 4  {'section': None, 'sec_number': '3.5', 'sec_ty...
#
#                                                 32    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Efficient LSH for MinHash Sketche...
# 3                                               None
# 4  {'section': None, 'sec_number': '3.5', 'sec_ty...
#
#                                                 33    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': 'The ARA Architecture', 'sec_numbe...
#
#                                                 34    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': None, 'sec_number': '4.1', 'sec_ty...
#
#                                                 35    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': None, 'sec_number': '4.1', 'sec_ty...
#
#                                                 36    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': None, 'sec_number': '4.1', 'sec_ty...
#
#                                                 37    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': None, 'sec_number': '4.1', 'sec_ty...
#
#                                                 38    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': None, 'sec_number': '4.1', 'sec_ty...
#
#                                                 39    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': None, 'sec_number': '4.1', 'sec_ty...
#
#                                                 40    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': 'Methodology', 'sec_number': '4.2'...
#
#                                                 41    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': 'Methodology', 'sec_number': '4.2'...
#
#                                                 42    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': 'Methodology', 'sec_number': '4.2'...
#
#                                                 43    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': 'Methodology', 'sec_number': '4.2'...
#
#                                                 44    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': 'Methodology', 'sec_number': '4.2'...
#
#                                                 45    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': 'Methodology', 'sec_number': '4.2'...
#
#                                                 46    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': 'Methodology', 'sec_number': '4.2'...
#
#                                                 47    \
# 0                                               None
# 1                                               None
# 2  {'section': 'The Complete Algorithm', 'sec_num...
# 3                                               None
# 4  {'section': 'Methodology', 'sec_number': '4.2'...
#
#                                                 48    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MinHash Generalization Properties...
# 3                                               None
# 4  {'section': 'Methodology', 'sec_number': '4.2'...
#
#                                                 49    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MinHash Generalization Properties...
# 3                                               None
# 4  {'section': 'Methodology', 'sec_number': '4.2'...
#
#                                                 50    \
# 0                                               None
# 1                                               None
# 2  {'section': 'PERFORMANCE EVALUATION', 'sec_num...
# 3                                               None
# 4  {'section': 'Data', 'sec_number': '4.3', 'sec_...
#
#                                                 51    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Experimental Setup', 'sec_number'...
# 3                                               None
# 4  {'section': 'Data', 'sec_number': '4.3', 'sec_...
#
#                                                 52    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Experimental Setup', 'sec_number'...
# 3                                               None
# 4  {'section': 'System Specification', 'sec_numbe...
#
#                                                 53    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Experimental Setup', 'sec_number'...
# 3                                               None
# 4  {'section': 'Result', 'sec_number': '5.1', 'se...
#
#                                                 54    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Experimental Setup', 'sec_number'...
# 3                                               None
# 4  {'section': 'Analysis', 'sec_number': '5.2', '...
#
#                                                 55    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Experimental Setup', 'sec_number'...
# 3                                               None
# 4  {'section': 'Comparison', 'sec_number': '5.3',...
#
#                                                 56    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Experimental Setup', 'sec_number'...
# 3                                               None
# 4  {'section': 'Conclusion', 'sec_number': '6', '...
#
#                                                 57    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Experimental Setup', 'sec_number'...
# 3                                               None
# 4  {'section': 'Conclusion', 'sec_number': '6', '...
#
#                                                 58    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Experimental Setup', 'sec_number'...
# 3                                               None
# 4  {'section': 'Conclusion', 'sec_number': '6', '...
#
#                                                 59    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Experimental Setup', 'sec_number'...
# 3                                               None
# 4  {'section': 'Conclusion', 'sec_number': '6', '...
#
#                                                 60    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Results for Simple RIAs', 'sec_nu...
# 3                                               None
# 4  {'section': 'Conflict of Interest', 'sec_numbe...
#
#                                                 61    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MinHash Results', 'sec_number': '...
# 3                                               None
# 4                                               None
#
#                                                 62    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MinHash Results', 'sec_number': '...
# 3                                               None
# 4                                               None
#
#                                                 63    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Results of Other Hash-Based Appro...
# 3                                               None
# 4                                               None
#
#                                                 64    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Results of Other Hash-Based Appro...
# 3                                               None
# 4                                               None
#
#                                                 65    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Results of Non Hash-Based Tools',...
# 3                                               None
# 4                                               None
#
#                                                 66    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Results for Complex RIAs', 'sec_n...
# 3                                               None
# 4                                               None
#
#                                                 67    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MinHash Results', 'sec_number': '...
# 3                                               None
# 4                                               None
#
#                                                 68    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MinHash Results', 'sec_number': '...
# 3                                               None
# 4                                               None
#
#                                                 69    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MinHash Results', 'sec_number': '...
# 3                                               None
# 4                                               None
#
#                                                 70    \
# 0                                               None
# 1                                               None
# 2  {'section': 'MinHash Results', 'sec_number': '...
# 3                                               None
# 4                                               None
#
#                                                 71    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Results of Other Hash-Based Appro...
# 3                                               None
# 4                                               None
#
#                                                 72    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Results of Other Hash-Based Appro...
# 3                                               None
# 4                                               None
#
#                                                 73    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Results of Non Hash-Based Tools',...
# 3                                               None
# 4                                               None
#
#                                                 74    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Results of Non Hash-Based Tools',...
# 3                                               None
# 4                                               None
#
#                                                 75    \
# 0                                               None
# 1                                               None
# 2  {'section': 'Results of Non Hash-Based Tools',...
# 3                                               None
# 4                                               None
#
#                                                 76    \
# 0                                               None
# 1                                               None
# 2  {'section': 'CONCLUSIONS', 'sec_number': '6', ...
# 3                                               None
# 4                                               None
#
#                                                 77    \
# 0                                               None
# 1                                               None
# 2  {'section': 'CONCLUSIONS', 'sec_number': '6', ...
# 3                                               None
# 4                                               None
#
#                                                 78    \
# 0                                               None
# 1                                               None
# 2  {'section': 'CONCLUSIONS', 'sec_number': '6', ...
# 3                                               None
# 4                                               None
#
#                                                 79    \
# 0                                               None
# 1                                               None
# 2  {'section': 'CONCLUSIONS', 'sec_number': '6', ...
# 3                                               None
# 4                                               None
#
#                                                 80    \
# 0                                               None
# 1                                               None
# 2  {'section': 'CONCLUSIONS', 'sec_number': '6', ...
# 3                                               None
# 4                                               None
#
#                                                 81    \
# 0                                               None
# 1                                               None
# 2  {'section': 'CONCLUSIONS', 'sec_number': '6', ...
# 3                                               None
# 4                                               None
#
#                                                 82    \
# 0                                               None
# 1                                               None
# 2  {'section': 'CONCLUSIONS', 'sec_number': '6', ...
# 3                                               None
# 4                                               None
#
#                                                 83    \
# 0                                               None
# 1                                               None
# 2  {'section': 'CONCLUSIONS', 'sec_number': '6', ...
# 3                                               None
# 4                                               None
#
#                                                 84    \
# 0                                               None
# 1                                               None
# 2  {'section': 'FUNDING', 'sec_number': '-1', 'se...
# 3                                               None
# 4                                               None
#
#                                                 85    86    87    88    89    \
# 0                                               None  None  None  None  None
# 1                                               None  None  None  None  None
# 2  {'section': 'ACKNOWLEDGEMENTS', 'sec_number': ...  None  None  None  None
# 3                                               None  None  None  None  None
# 4                                               None  None  None  None  None
#
#    90    91    92    93    94    95    96    97    98    99    100   101   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    102   103   104   105   106   107   108   109   110   111   112   113   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    114   115   116   117   118   119   120   121   122   123   124   125   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    126   127   128   129   130   131   132   133   134   135   136   137   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    138   139   140   141   142   143   144   145   146   147   148   149   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    150   151   152   153   154   155   156   157   158   159   160   161   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    162   163   164   165   166   167   168   169   170   171   172   173   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    174   175   176   177   178   179   180   181   182   183   184   185   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    186   187   188   189   190   191   192   193   194   195   196   197   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    198   199   200   201   202   203   204   205   206   207   208   209   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    210   211   212   213   214   215   216   217   218   219   220   221   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    222   223   224   225   226   227   228   229   230   231   232   233   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    234   235   236   237   238   239   240   241   242   243   244   245   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    246   247   248   249   250   251   252   253   254   255   256   257   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    258   259   260   261   262   263   264   265   266   267   268   269   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    270   271   272   273   274   275   276   277   278   279   280   281   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    282   283   284   285   286   287   288   289   290   291   292   293   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    294   295   296   297   298   299   300   301   302   303   304   305   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    306   307   308   309   310   311   312   313   314   315   316   317   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    318   319   320   321   322   323   324   325   326   327   328   329   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    330   331   332   333   334   335   336   337   338   339   340   341   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    342   343   344   345   346   347   348   349   350   351   352   353   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    354   355   356   357   358   359   360   361   362   363   364   365   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    366   367   368   369   370   371   372   373   374   375   376   377   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    378   379   380   381   382   383   384   385   386   387   388   389   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    390   391   392   393   394   395   396   397   398   399   400   401   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    402   403   404   405   406   407   408   409   410   411   412   413   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    414   415   416   417   418   419   420   421   422   423   424   425   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    426   427   428   429   430   431   432   433   434   435   436   437   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    438   439   440   441   442   443   444   445   446   447   448   449   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    450   451   452   453   454   455   456   457   458   459   460   461   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    462   463   464   465   466   467   468   469   470   471   472   473   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    474   475   476   477   478   479   480   481   482   483   484   485   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    486   487   488   489   490   491   492   493   494   495   496   497   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    498   499   500   501   502   503   504   505   506   507   508   509   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    510   511   512   513   514   515   516   517   518   519   520   521   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    522   523   524   525   526   527   528   529   530   531   532   533   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    534   535   536   537   538   539   540   541   542   543   544   545   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    546   547   548   549   550   551   552   553   554   555   556   557   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    558   559   560   561   562   563   564   565   566   567   568   569   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    570   571   572   573   574   575   576   577   578   579   580   581   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# ...
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    762   763   764   765   766   767   768   769   770   771   772   773   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    774   775   776   777   778   779   780   781   782   783   784   785   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    786   787   788   789   790   791   792   793   794   795   796   797   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    798   799   800   801   802   803   804   805   806   807   808   809   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    810   811   812   813   814   815   816   817   818   819   820   821   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    822   823   824   825   826   827   828   829   830   831   832   833   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    834   835   836   837   838   839   840   841   842   843   844   845   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    846   847   848   849   850   851   852   853   854   855   856   857   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    858   859   860   861   862   863   864   865   866   867   868   869   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    870   871   872   873   874   875   876   877   878   879   880   881   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    882   883   884   885   886   887   888   889   890   891   892   893   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    894   895   896   897   898   899   900   901   902   903   904   905   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    906   907   908   909   910   911   912   913   914   915   916   917   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    918   919   920   921   922   923   924   925   926   927   928   929   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    930   931   932   933   934   935   936   937   938   939   940   941   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    942   943   944   945   946   947   948   949   950   951   952   953   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    954   955   956   957   958   959   960   961   962   963   964   965   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    966   967   968   969   970   971   972   973   974   975   976   977   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    978   979   980   981   982   983   984   985   986   987   988   989   \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    990   991   992   993   994   995   996   997   998   999   1000  1001  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1002  1003  1004  1005  1006  1007  1008  1009  1010  1011  1012  1013  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1014  1015  1016  1017  1018  1019  1020  1021  1022  1023  1024  1025  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1026  1027  1028  1029  1030  1031  1032  1033  1034  1035  1036  1037  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1038  1039  1040  1041  1042  1043  1044  1045  1046  1047  1048  1049  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1050  1051  1052  1053  1054  1055  1056  1057  1058  1059  1060  1061  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1062  1063  1064  1065  1066  1067  1068  1069  1070  1071  1072  1073  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1074  1075  1076  1077  1078  1079  1080  1081  1082  1083  1084  1085  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1086  1087  1088  1089  1090  1091  1092  1093  1094  1095  1096  1097  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1098  1099  1100  1101  1102  1103  1104  1105  1106  1107  1108  1109  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1110  1111  1112  1113  1114  1115  1116  1117  1118  1119  1120  1121  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1122  1123  1124  1125  1126  1127  1128  1129  1130  1131  1132  1133  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1134  1135  1136  1137  1138  1139  1140  1141  1142  1143  1144  1145  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1146  1147  1148  1149  1150  1151  1152  1153  1154  1155  1156  1157  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1158  1159  1160  1161  1162  1163  1164  1165  1166  1167  1168  1169  \
# 0  None  None  None  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None  None  None  None
#
#    1170  1171  1172
# 0  None  None  None
# 1  None  None  None
# 2  None  None  None
# 3  None  None  None
# 4  None  None  None

# %%
# %time reference = pd.DataFrame([md for md in df.ref_entries])
# reference.head()

# %%
# import matplotlib.pyplot as plt

# # Assuming you have a column 'abstract' in your DataFrame, you can visualize its value counts
# df['abstract'].value_counts().plot(kind='bar')
# plt.show()

# %%
df.columns
# Out:
# Index(['paper_id', '_pdf_hash', '_source_hash', '_source_name', 'metadata',
#        'discipline', 'abstract', 'body_text', 'bib_entries', 'ref_entries'],
#       dtype='object')

# %%
df1 = df[['paper_id','discipline','metadata','abstract','body_text']]
df1.head()
# Out:
#      paper_id  discipline                                           metadata  \
# 0  2001.00542     Physics  {'id': '2001.00542', 'submitter': 'Uro\v{s} Tk...
# 1  2001.00552     Physics  {'id': '2001.00552', 'submitter': 'Uro\v{s} Tk...
# 2  2001.01128  Statistics  {'id': '2001.01128', 'submitter': 'Ilan Ben-Ba...
# 3  2001.01237     Physics  {'id': '2001.01237', 'submitter': 'Ligong Bian...
# 4  2001.01618  Statistics  {'id': '2001.01618', 'submitter': 'Sudipta Pau...
#
#                                             abstract  \
# 0  {'section': 'Abstract', 'text': '  Compared to...
# 1  {'section': 'Abstract', 'text': '  Pure liquid...
# 2  {'section': 'Abstract', 'text': '  Web applica...
# 3  {'section': 'Abstract', 'text': '  We study st...
# 4  {'section': 'Abstract', 'text': '  Differentia...
#
#                                            body_text
# 0  [{'section': '', 'sec_number': '-1', 'sec_type...
# 1  [{'section': '', 'sec_number': '-1', 'sec_type...
# 2  [{'section': 'INTRODUCTION', 'sec_number': '1'...
# 3  [{'section': 'Supplemental material', 'sec_num...
# 4  [{'section': 'Introduction', 'sec_number': '1'...

# %%
df1 = pd.concat([df1, metadata], axis=1)

# %%
df1.head()
# Out:
#      paper_id  discipline                                           metadata  \
# 0  2001.00542     Physics  {'id': '2001.00542', 'submitter': 'Uro\v{s} Tk...
# 1  2001.00552     Physics  {'id': '2001.00552', 'submitter': 'Uro\v{s} Tk...
# 2  2001.01128  Statistics  {'id': '2001.01128', 'submitter': 'Ilan Ben-Ba...
# 3  2001.01237     Physics  {'id': '2001.01237', 'submitter': 'Ligong Bian...
# 4  2001.01618  Statistics  {'id': '2001.01618', 'submitter': 'Sudipta Pau...
#
#                                             abstract  \
# 0  {'section': 'Abstract', 'text': '  Compared to...
# 1  {'section': 'Abstract', 'text': '  Pure liquid...
# 2  {'section': 'Abstract', 'text': '  Web applica...
# 3  {'section': 'Abstract', 'text': '  We study st...
# 4  {'section': 'Abstract', 'text': '  Differentia...
#
#                                            body_text          id  \
# 0  [{'section': '', 'sec_number': '-1', 'sec_type...  2001.00542
# 1  [{'section': '', 'sec_number': '-1', 'sec_type...  2001.00552
# 2  [{'section': 'INTRODUCTION', 'sec_number': '1'...  2001.01128
# 3  [{'section': 'Supplemental material', 'sec_num...  2001.01237
# 4  [{'section': 'Introduction', 'sec_number': '1'...  2001.01618
#
#           submitter                                            authors  \
# 0   Uro\v{s} Tkalec  Simon \v{C}opar, \v{Z}iga Kos, Tadej Emer\v{s}...
# 1   Uro\v{s} Tkalec  Tadej Emer\v{s}i\v{c}, Rui Zhang, \v{Z}iga Kos...
# 2   Ilan Ben-Bassat                     Ilan Ben-Bassat and Erez Rokah
# 3       Ligong Bian                            Ruiyu Zhou, Ligong Bian
# 4  Sudipta Paul Ms.                  Sudipta Paul and Subhankar Mishra
#
#                                                title  \
# 0  Microfluidic control over topological states i...
# 1        Sculpting stable structures in pure liquids
# 2  Locality-Sensitive Hashing for Efficient Web A...
# 3  Gravitational wave and electroweak baryogenesi...
# 4  ARA : Aggregated RAPPOR and Analysis for Centr...
#
#                                     comments  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3  7 pages, 5 figures, PLB published version
# 4                                       None
#
#                                          journal-ref  \
# 0          Nature Communications, vol. 11, 59 (2020)
# 1          Science Advances, vol. 5, eaav4283 (2019)
# 2  In Proceedings of the 5th International Confer...
# 3                      Phys.Lett.B 829 (2022) 137105
# 4                       SN COMPUT. SCI. (2020) 1: 22
#
#                               doi report-no           categories  \
# 0      10.1038/s41467-019-13789-9      None        cond-mat.soft
# 1          10.1126/sciadv.aav4283      None        cond-mat.soft
# 2        10.5220/0007255301930204      None  cs.CR cs.LG stat.ML
# 3  10.1016/j.physletb.2022.137105      None   hep-ph astro-ph.CO
# 4       10.1007/s42979-019-0023-y      None  cs.CR cs.LG stat.ML
#
#                                        license  \
# 0  http://creativecommons.org/licenses/by/4.0/
# 1  http://creativecommons.org/licenses/by/4.0/
# 2  http://creativecommons.org/licenses/by/4.0/
# 3  http://creativecommons.org/licenses/by/4.0/
# 4  http://creativecommons.org/licenses/by/4.0/
#
#                                             abstract  \
# 0    Compared to isotropic liquids, orientational...
# 1    Pure liquids in thermodynamic equilibrium ar...
# 2    Web application security has become a major ...
# 3    We study stochastic gravitational wave produ...
# 4    Differential privacy(DP) has now become a st...
#
#                                             versions update_date  \
# 0  [{'version': 'v1', 'created': 'Thu, 2 Jan 2020...  2020-01-03
# 1  [{'version': 'v1', 'created': 'Thu, 2 Jan 2020...  2020-01-03
# 2  [{'version': 'v1', 'created': 'Sat, 4 Jan 2020...  2020-01-07
# 3  [{'version': 'v1', 'created': 'Sun, 5 Jan 2020...  2022-04-19
# 4  [{'version': 'v1', 'created': 'Mon, 6 Jan 2020...  2020-01-07
#
#                                       authors_parsed
# 0  [[Čopar, Simon, ], [Kos, Žiga, ], [Emeršič, Ta...
# 1  [[Emeršič, Tadej, ], [Zhang, Rui, ], [Kos, Žig...
# 2            [[Ben-Bassat, Ilan, ], [Rokah, Erez, ]]
# 3                [[Zhou, Ruiyu, ], [Bian, Ligong, ]]
# 4         [[Paul, Sudipta, ], [Mishra, Subhankar, ]]

# %%
df1 = df1.drop(['id', 'metadata'], axis=1)

# %%
df1 = pd.concat([df1, abstract], axis=1)
df1.head()
# Out:
#      paper_id  discipline                                           abstract  \
# 0  2001.00542     Physics  {'section': 'Abstract', 'text': '  Compared to...
# 1  2001.00552     Physics  {'section': 'Abstract', 'text': '  Pure liquid...
# 2  2001.01128  Statistics  {'section': 'Abstract', 'text': '  Web applica...
# 3  2001.01237     Physics  {'section': 'Abstract', 'text': '  We study st...
# 4  2001.01618  Statistics  {'section': 'Abstract', 'text': '  Differentia...
#
#                                            body_text         submitter  \
# 0  [{'section': '', 'sec_number': '-1', 'sec_type...   Uro\v{s} Tkalec
# 1  [{'section': '', 'sec_number': '-1', 'sec_type...   Uro\v{s} Tkalec
# 2  [{'section': 'INTRODUCTION', 'sec_number': '1'...   Ilan Ben-Bassat
# 3  [{'section': 'Supplemental material', 'sec_num...       Ligong Bian
# 4  [{'section': 'Introduction', 'sec_number': '1'...  Sudipta Paul Ms.
#
#                                              authors  \
# 0  Simon \v{C}opar, \v{Z}iga Kos, Tadej Emer\v{s}...
# 1  Tadej Emer\v{s}i\v{c}, Rui Zhang, \v{Z}iga Kos...
# 2                     Ilan Ben-Bassat and Erez Rokah
# 3                            Ruiyu Zhou, Ligong Bian
# 4                  Sudipta Paul and Subhankar Mishra
#
#                                                title  \
# 0  Microfluidic control over topological states i...
# 1        Sculpting stable structures in pure liquids
# 2  Locality-Sensitive Hashing for Efficient Web A...
# 3  Gravitational wave and electroweak baryogenesi...
# 4  ARA : Aggregated RAPPOR and Analysis for Centr...
#
#                                     comments  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3  7 pages, 5 figures, PLB published version
# 4                                       None
#
#                                          journal-ref  \
# 0          Nature Communications, vol. 11, 59 (2020)
# 1          Science Advances, vol. 5, eaav4283 (2019)
# 2  In Proceedings of the 5th International Confer...
# 3                      Phys.Lett.B 829 (2022) 137105
# 4                       SN COMPUT. SCI. (2020) 1: 22
#
#                               doi report-no           categories  \
# 0      10.1038/s41467-019-13789-9      None        cond-mat.soft
# 1          10.1126/sciadv.aav4283      None        cond-mat.soft
# 2        10.5220/0007255301930204      None  cs.CR cs.LG stat.ML
# 3  10.1016/j.physletb.2022.137105      None   hep-ph astro-ph.CO
# 4       10.1007/s42979-019-0023-y      None  cs.CR cs.LG stat.ML
#
#                                        license  \
# 0  http://creativecommons.org/licenses/by/4.0/
# 1  http://creativecommons.org/licenses/by/4.0/
# 2  http://creativecommons.org/licenses/by/4.0/
# 3  http://creativecommons.org/licenses/by/4.0/
# 4  http://creativecommons.org/licenses/by/4.0/
#
#                                             abstract  \
# 0    Compared to isotropic liquids, orientational...
# 1    Pure liquids in thermodynamic equilibrium ar...
# 2    Web application security has become a major ...
# 3    We study stochastic gravitational wave produ...
# 4    Differential privacy(DP) has now become a st...
#
#                                             versions update_date  \
# 0  [{'version': 'v1', 'created': 'Thu, 2 Jan 2020...  2020-01-03
# 1  [{'version': 'v1', 'created': 'Thu, 2 Jan 2020...  2020-01-03
# 2  [{'version': 'v1', 'created': 'Sat, 4 Jan 2020...  2020-01-07
# 3  [{'version': 'v1', 'created': 'Sun, 5 Jan 2020...  2022-04-19
# 4  [{'version': 'v1', 'created': 'Mon, 6 Jan 2020...  2020-01-07
#
#                                       authors_parsed   section  \
# 0  [[Čopar, Simon, ], [Kos, Žiga, ], [Emeršič, Ta...  Abstract
# 1  [[Emeršič, Tadej, ], [Zhang, Rui, ], [Kos, Žig...  Abstract
# 2            [[Ben-Bassat, Ilan, ], [Rokah, Erez, ]]  Abstract
# 3                [[Zhou, Ruiyu, ], [Bian, Ligong, ]]  Abstract
# 4         [[Paul, Sudipta, ], [Mishra, Subhankar, ]]  Abstract
#
#                                                 text cite_spans ref_spans
# 0    Compared to isotropic liquids, orientational...         []        []
# 1    Pure liquids in thermodynamic equilibrium ar...         []        []
# 2    Web application security has become a major ...         []        []
# 3    We study stochastic gravitational wave produ...         []        []
# 4    Differential privacy(DP) has now become a st...         []        []

# %%
df1 = pd.concat([df1, body], axis=1)
df1.head(20)
# Out:
#       paper_id        discipline  \
# 0   2001.00542           Physics
# 1   2001.00552           Physics
# 2   2001.01128        Statistics
# 3   2001.01237           Physics
# 4   2001.01618        Statistics
# 5   2001.01982  Computer Science
# 6   2001.03256  Computer Science
# 7   2001.04292  Computer Science
# 8   2001.04392  Computer Science
# 9   2001.04771           Physics
# 10  2001.06885       Mathematics
# 11  2001.07774           Physics
# 12  2001.08332           Physics
# 13  2001.08479       Mathematics
# 14  2001.08614  Computer Science
# 15  2001.09165           Physics
# 16  2001.09225        Statistics
# 17  2001.10487  Computer Science
# 18  2001.10368           Physics
# 19  2001.10741        Statistics
#
#                                              abstract  \
# 0   {'section': 'Abstract', 'text': '  Compared to...
# 1   {'section': 'Abstract', 'text': '  Pure liquid...
# 2   {'section': 'Abstract', 'text': '  Web applica...
# 3   {'section': 'Abstract', 'text': '  We study st...
# 4   {'section': 'Abstract', 'text': '  Differentia...
# 5   {'section': 'Abstract', 'text': '  This work p...
# 6   {'section': 'Abstract', 'text': '  Solidity is...
# 7   {'section': 'Abstract', 'text': '  This paper ...
# 8   {'section': 'Abstract', 'text': '  We introduc...
# 9   {'section': 'Abstract', 'text': '  The advent ...
# 10  {'section': 'Abstract', 'text': '  We present ...
# 11  {'section': 'Abstract', 'text': '  The causal ...
# 12  {'section': 'Abstract', 'text': '  Recent whol...
# 13  {'section': 'Abstract', 'text': '  In this pap...
# 14  {'section': 'Abstract', 'text': '  Wikipedia, ...
# 15  {'section': 'Abstract', 'text': '  We report a...
# 16  {'section': 'Abstract', 'text': '  Prediction ...
# 17  {'section': 'Abstract', 'text': '  This paper ...
# 18  {'section': 'Abstract', 'text': '  Quasars acc...
# 19  {'section': 'Abstract', 'text': '  Algorithm s...
#
#                                             body_text             submitter  \
# 0   [{'section': '', 'sec_number': '-1', 'sec_type...       Uro\v{s} Tkalec
# 1   [{'section': '', 'sec_number': '-1', 'sec_type...       Uro\v{s} Tkalec
# 2   [{'section': 'INTRODUCTION', 'sec_number': '1'...       Ilan Ben-Bassat
# 3   [{'section': 'Supplemental material', 'sec_num...           Ligong Bian
# 4   [{'section': 'Introduction', 'sec_number': '1'...      Sudipta Paul Ms.
# 5   [{'section': 'Introduction', 'sec_number': '1'...       Guido Schillaci
# 6   [{'section': 'Introduction', 'sec_number': '1'...          \'Akos Hajdu
# 7   [{'section': 'Introduction', 'sec_number': '1'...          WaiChing Sun
# 8   [{'section': 'Introduction', 'sec_number': '1'...    Karoliina Lehtinen
# 9   [{'section': 'Introduction', 'sec_number': '1'...          Imen Zemzemi
# 10  [{'section': 'Introduction', 'sec_number': '1'...          Sai Sidhardh
# 11  [{'section': 'Introduction ', 'sec_number': '1...          Robin Lorenz
# 12  [{'section': 'Abstract', 'sec_number': '-1', '...        Megan Morrison
# 13  [{'section': 'Introduction', 'sec_number': '1'...     Kishor Kucche Dr.
# 14  [{'section': 'Introduction', 'sec_number': '1'...      Tiziano Piccardi
# 15  [{'section': '', 'sec_number': '-1', 'sec_type...        Stuart Thomson
# 16  [{'section': 'Introduction', 'sec_number': '1'...           Ryan Martin
# 17  [{'section': 'Introduction', 'sec_number': '1'...  Ali Ahmadi Dastjerdi
# 18  [{'section': 'Keywords:', 'sec_number': '1', '...        Paola Marziani
# 19  [{'section': 'Introduction', 'sec_number': '1'...     Alexander Tornede
#
#                                               authors  \
# 0   Simon \v{C}opar, \v{Z}iga Kos, Tadej Emer\v{s}...
# 1   Tadej Emer\v{s}i\v{c}, Rui Zhang, \v{Z}iga Kos...
# 2                      Ilan Ben-Bassat and Erez Rokah
# 3                             Ruiyu Zhou, Ligong Bian
# 4                   Sudipta Paul and Subhankar Mishra
# 5   Guido Schillaci, Antonio Pico Villalpando, Ver...
# 6                     \'Akos Hajdu, Dejan Jovanovi\'c
# 7              Nikolaos Vlassis, Ran Ma, WaiChing Sun
# 8            Karoliina Lehtinen and Martin Zimmermann
# 9        Imen Zemzemi, Francesco Massimo, Arnaud Beck
# 10  Sansit Patnaik, Sai Sidhardh, and Fabio Semper...
# 11                  Robin Lorenz and Jonathan Barrett
# 12  Megan Morrison, Charles Fieseler, and J. Natha...
# 13                  Ashwini D. Mali, Kishor D. Kucche
# 14  Tiziano Piccardi, Miriam Redi, Giovanni Colavi...
# 15  Stuart J. Thomson, Miles M. P. Couchman, John ...
# 16                     Leonardo Cella and Ryan Martin
# 17  Ali Ahmadi Dastjerdi, A.Astolfi, Niranjan Saik...
# 18  D. Dultzin, P. Marziani, J. A. de Diego, C. A....
# 19  Alexander Tornede, Marcel Wever, Eyke H\"uller...
#
#                                                 title  \
# 0   Microfluidic control over topological states i...
# 1         Sculpting stable structures in pure liquids
# 2   Locality-Sensitive Hashing for Efficient Web A...
# 3   Gravitational wave and electroweak baryogenesi...
# 4   ARA : Aggregated RAPPOR and Analysis for Centr...
# 5   Intrinsic Motivation and Episodic Memories for...
# 6   SMT-Friendly Formalization of the Solidity Mem...
# 7   Geometric deep learning for computational mech...
# 8           Good-for-games $\omega$-Pushdown Automata
# 9   Azimuthal decomposition study of a realistic l...
# 10  A Ritz-based Finite Element Method for a Fract...
# 11  Causal and compositional structure of unitary ...
# 12       Nonlinear control in the nematode C. elegans
# 13  Nonlocal Boundary Value Problem for Generalize...
# 14  Quantifying Engagement with Citations on Wikip...
# 15  Collective vibrations of confined levitating d...
# 16  Validity, consonant plausibility measures, and...
# 17  Closed-Loop Frequency Analysis of Reset Contro...
# 18  Extreme quasars as distance indicators in cosm...
# 19  Extreme Algorithm Selection With Dyadic Featur...
#
#                                              comments  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3           7 pages, 5 figures, PLB published version
# 4                                                None
# 5   This manuscript has been submitted for conside...
# 6   Authors' manuscript. Published in P. M\"uller ...
# 7                                                None
# 8   Extended version of LICS'20 paper of the same ...
# 9   7 pages, 5 figures, submitted to the 4th EAAC ...
# 10  35 pages, 10 figures, 2 tables. In revised ver...
# 11                               46 pages, 60 figures
# 12                                               None
# 13                                                 24
# 14              The Web Conference WWW 2020, 10 pages
# 15          15 pages (incl. references) and 4 figures
# 16  34 pages, 2 figures, 2 tables. Comments welcom...
# 17                                               None
# 18                                21 pages, 3 figures
# 19                Published at Discovery Science 2020
#
#                                           journal-ref  \
# 0           Nature Communications, vol. 11, 59 (2020)
# 1           Science Advances, vol. 5, eaav4283 (2019)
# 2   In Proceedings of the 5th International Confer...
# 3                       Phys.Lett.B 829 (2022) 137105
# 4                        SN COMPUT. SCI. (2020) 1: 22
# 5                             Adaptive behaviour 2020
# 6                                                None
# 7                                                None
# 8   Logical Methods in Computer Science, Volume 18...
# 9                                                None
# 10                                               None
# 11                              Quantum 5, 511 (2021)
# 12                                               None
# 13  Mathematical Methods in the Applied Sciences (...
# 14                                               None
# 15                 Phys. Rev. Fluids 5, 083601 (2020)
# 16  International Journal of Approximate Reasoning...
# 17                                               None
# 18              Front. Astron. Space Sci. 6:80 (2020)
# 19                                               None
#
#                                 doi report-no  \
# 0        10.1038/s41467-019-13789-9      None
# 1            10.1126/sciadv.aav4283      None
# 2          10.5220/0007255301930204      None
# 3    10.1016/j.physletb.2022.137105      None
# 4         10.1007/s42979-019-0023-y      None
# 5          10.1177/1059712320922916      None
# 6       10.1007/978-3-030-44914-8_9      None
# 7         10.1016/j.cma.2020.113299      None
# 8         10.46298/lmcs-18(1:3)2022      None
# 9   10.1088/1742-6596/1596/1/012054      None
# 10   10.1016/j.ijsolstr.2020.05.034      None
# 11        10.22331/q-2021-07-28-511      None
# 12                             None      None
# 13                 10.1002/mma.6521      None
# 14                             None      None
# 15   10.1103/PhysRevFluids.5.083601      None
# 16       10.1016/j.ijar.2021.07.013      None
# 17                             None      None
# 18         10.3389/fspas.2019.00080      None
# 19     10.1007/978-3-030-61527-7_21      None
#
#                                          categories  \
# 0                                     cond-mat.soft
# 1                                     cond-mat.soft
# 2                               cs.CR cs.LG stat.ML
# 3                                hep-ph astro-ph.CO
# 4                               cs.CR cs.LG stat.ML
# 5                                 cs.AI cs.LG cs.RO
# 6                                 cs.PL cs.LO cs.SE
# 7                                             cs.LG
# 8                                       cs.FL cs.GT
# 9   physics.comp-ph physics.acc-ph physics.plasm-ph
# 10                            math.NA cs.NA math.AP
# 11                                         quant-ph
# 12                  q-bio.NC math.DS physics.bio-ph
# 13                                          math.DS
# 14                                            cs.CY
# 15                    cond-mat.soft math.DS nlin.PS
# 16                          math.ST stat.ML stat.TH
# 17                                    eess.SY cs.SY
# 18                          astro-ph.CO astro-ph.GA
# 19                                    cs.LG stat.ML
#
#                                               license  \
# 0         http://creativecommons.org/licenses/by/4.0/
# 1         http://creativecommons.org/licenses/by/4.0/
# 2         http://creativecommons.org/licenses/by/4.0/
# 3         http://creativecommons.org/licenses/by/4.0/
# 4         http://creativecommons.org/licenses/by/4.0/
# 5         http://creativecommons.org/licenses/by/4.0/
# 6         http://creativecommons.org/licenses/by/4.0/
# 7         http://creativecommons.org/licenses/by/4.0/
# 8         http://creativecommons.org/licenses/by/4.0/
# 9         http://creativecommons.org/licenses/by/4.0/
# 10        http://creativecommons.org/licenses/by/4.0/
# 11        http://creativecommons.org/licenses/by/4.0/
# 12        http://creativecommons.org/licenses/by/4.0/
# 13        http://creativecommons.org/licenses/by/4.0/
# 14        http://creativecommons.org/licenses/by/4.0/
# 15        http://creativecommons.org/licenses/by/4.0/
# 16        http://creativecommons.org/licenses/by/4.0/
# 17  http://creativecommons.org/publicdomain/zero/1.0/
# 18        http://creativecommons.org/licenses/by/4.0/
# 19        http://creativecommons.org/licenses/by/4.0/
#
#                                              abstract  \
# 0     Compared to isotropic liquids, orientational...
# 1     Pure liquids in thermodynamic equilibrium ar...
# 2     Web application security has become a major ...
# 3     We study stochastic gravitational wave produ...
# 4     Differential privacy(DP) has now become a st...
# 5     This work presents an architecture that gene...
# 6     Solidity is the dominant programming languag...
# 7     This paper is the first attempt to use geome...
# 8     We introduce good-for-games $\omega$-pushdow...
# 9     The advent of ultra short high intensity las...
# 10    We present the analytical formulation and th...
# 11    The causal structure of a unitary transforma...
# 12    Recent whole-brain calcium imaging recording...
# 13    In this paper, we derive the equivalent frac...
# 14    Wikipedia, the free online encyclopedia that...
# 15    We report a new type of fluid-based driven d...
# 16    Prediction of future observations is an impo...
# 17    This paper introduces a closed-loop frequenc...
# 18    Quasars accreting matter at very high rates ...
# 19    Algorithm selection (AS) deals with selectin...
#
#                                              versions update_date  \
# 0   [{'version': 'v1', 'created': 'Thu, 2 Jan 2020...  2020-01-03
# 1   [{'version': 'v1', 'created': 'Thu, 2 Jan 2020...  2020-01-03
# 2   [{'version': 'v1', 'created': 'Sat, 4 Jan 2020...  2020-01-07
# 3   [{'version': 'v1', 'created': 'Sun, 5 Jan 2020...  2022-04-19
# 4   [{'version': 'v1', 'created': 'Mon, 6 Jan 2020...  2020-01-07
# 5   [{'version': 'v1', 'created': 'Tue, 7 Jan 2020...  2020-06-09
# 6   [{'version': 'v1', 'created': 'Thu, 9 Jan 2020...  2020-04-20
# 7   [{'version': 'v1', 'created': 'Wed, 8 Jan 2020...  2020-10-12
# 8   [{'version': 'v1', 'created': 'Mon, 13 Jan 202...  2022-03-14
# 9   [{'version': 'v1', 'created': 'Tue, 14 Jan 202...  2020-12-30
# 10  [{'version': 'v1', 'created': 'Sun, 19 Jan 202...  2021-02-11
# 11  [{'version': 'v1', 'created': 'Tue, 21 Jan 202...  2021-07-28
# 12  [{'version': 'v1', 'created': 'Thu, 23 Jan 202...  2020-02-05
# 13  [{'version': 'v1', 'created': 'Thu, 23 Jan 202...  2020-06-23
# 14  [{'version': 'v1', 'created': 'Thu, 23 Jan 202...  2020-01-28
# 15  [{'version': 'v1', 'created': 'Fri, 24 Jan 202...  2020-10-27
# 16  [{'version': 'v1', 'created': 'Fri, 24 Jan 202...  2022-06-13
# 17  [{'version': 'v1', 'created': 'Tue, 28 Jan 202...  2020-11-25
# 18  [{'version': 'v1', 'created': 'Tue, 28 Jan 202...  2020-01-29
# 19  [{'version': 'v1', 'created': 'Wed, 29 Jan 202...  2020-10-23
#
#                                        authors_parsed   section  \
# 0   [[Čopar, Simon, ], [Kos, Žiga, ], [Emeršič, Ta...  Abstract
# 1   [[Emeršič, Tadej, ], [Zhang, Rui, ], [Kos, Žig...  Abstract
# 2             [[Ben-Bassat, Ilan, ], [Rokah, Erez, ]]  Abstract
# 3                 [[Zhou, Ruiyu, ], [Bian, Ligong, ]]  Abstract
# 4          [[Paul, Sudipta, ], [Mishra, Subhankar, ]]  Abstract
# 5   [[Schillaci, Guido, ], [Villalpando, Antonio P...  Abstract
# 6             [[Hajdu, Ákos, ], [Jovanović, Dejan, ]]  Abstract
# 7   [[Vlassis, Nikolaos, ], [Ma, Ran, ], [Sun, Wai...  Abstract
# 8   [[Lehtinen, Karoliina, ], [Zimmermann, Martin, ]]  Abstract
# 9   [[Zemzemi, Imen, ], [Massimo, Francesco, ], [B...  Abstract
# 10  [[Patnaik, Sansit, ], [Sidhardh, Sai, ], [Semp...  Abstract
# 11         [[Lorenz, Robin, ], [Barrett, Jonathan, ]]  Abstract
# 12  [[Morrison, Megan, ], [Fieseler, Charles, ], [...  Abstract
# 13      [[Mali, Ashwini D., ], [Kucche, Kishor D., ]]  Abstract
# 14  [[Piccardi, Tiziano, ], [Redi, Miriam, ], [Col...  Abstract
# 15  [[Thomson, Stuart J., ], [Couchman, Miles M. P...  Abstract
# 16            [[Cella, Leonardo, ], [Martin, Ryan, ]]  Abstract
# 17  [[Dastjerdi, Ali Ahmadi, ], [Astolfi, A., ], [...  Abstract
# 18  [[Dultzin, D., ], [Marziani, P., ], [de Diego,...  Abstract
# 19  [[Tornede, Alexander, ], [Wever, Marcel, ], [H...  Abstract
#
#                                                  text cite_spans ref_spans  \
# 0     Compared to isotropic liquids, orientational...         []        []
# 1     Pure liquids in thermodynamic equilibrium ar...         []        []
# 2     Web application security has become a major ...         []        []
# 3     We study stochastic gravitational wave produ...         []        []
# 4     Differential privacy(DP) has now become a st...         []        []
# 5     This work presents an architecture that gene...         []        []
# 6     Solidity is the dominant programming languag...         []        []
# 7     This paper is the first attempt to use geome...         []        []
# 8     We introduce good-for-games $\omega$-pushdow...         []        []
# 9     The advent of ultra short high intensity las...         []        []
# 10    We present the analytical formulation and th...         []        []
# 11    The causal structure of a unitary transforma...         []        []
# 12    Recent whole-brain calcium imaging recording...         []        []
# 13    In this paper, we derive the equivalent frac...         []        []
# 14    Wikipedia, the free online encyclopedia that...         []        []
# 15    We report a new type of fluid-based driven d...         []        []
# 16    Prediction of future observations is an impo...         []        []
# 17    This paper introduces a closed-loop frequenc...         []        []
# 18    Quasars accreting matter at very high rates ...         []        []
# 19    Algorithm selection (AS) deals with selectin...         []        []
#
#                                                     0  \
# 0   {'section': '', 'sec_number': '-1', 'sec_type'...
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3   {'section': 'Supplemental material', 'sec_numb...
# 4   {'section': 'Introduction', 'sec_number': '1',...
# 5   {'section': 'Introduction', 'sec_number': '1',...
# 6   {'section': 'Introduction', 'sec_number': '1',...
# 7   {'section': 'Introduction', 'sec_number': '1',...
# 8   {'section': 'Introduction', 'sec_number': '1',...
# 9   {'section': 'Introduction', 'sec_number': '1',...
# 10  {'section': 'Introduction', 'sec_number': '1',...
# 11  {'section': 'Introduction ', 'sec_number': '1'...
# 12  {'section': 'Abstract', 'sec_number': '-1', 's...
# 13  {'section': 'Introduction', 'sec_number': '1',...
# 14  {'section': 'Introduction', 'sec_number': '1',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Introduction', 'sec_number': '1',...
# 17  {'section': 'Introduction', 'sec_number': '1',...
# 18  {'section': 'Keywords:', 'sec_number': '1', 's...
# 19  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                     1  \
# 0   {'section': '', 'sec_number': '-1', 'sec_type'...
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3   {'section': 'Supplemental material', 'sec_numb...
# 4   {'section': 'Introduction', 'sec_number': '1',...
# 5   {'section': 'Introduction', 'sec_number': '1',...
# 6   {'section': 'Introduction', 'sec_number': '1',...
# 7   {'section': 'Introduction', 'sec_number': '1',...
# 8   {'section': 'Introduction', 'sec_number': '1',...
# 9   {'section': 'Introduction', 'sec_number': '1',...
# 10  {'section': 'Introduction', 'sec_number': '1',...
# 11  {'section': 'Introduction ', 'sec_number': '1'...
# 12  {'section': 'Author summary', 'sec_number': '-...
# 13  {'section': 'Introduction', 'sec_number': '1',...
# 14  {'section': 'Introduction', 'sec_number': '1',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Introduction', 'sec_number': '1',...
# 17  {'section': 'Introduction', 'sec_number': '1',...
# 18  {'section': 'Introduction', 'sec_number': '2',...
# 19  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                     2  \
# 0   {'section': '', 'sec_number': '-1', 'sec_type'...
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3   {'section': 'Supplemental material', 'sec_numb...
# 4   {'section': 'Introduction', 'sec_number': '1',...
# 5   {'section': 'Introduction', 'sec_number': '1',...
# 6   {'section': 'Introduction', 'sec_number': '1',...
# 7   {'section': 'Introduction', 'sec_number': '1',...
# 8   {'section': 'Introduction', 'sec_number': '1',...
# 9   {'section': 'Review of the Azimuthal Fourier d...
# 10  {'section': 'Introduction', 'sec_number': '1',...
# 11  {'section': 'Introduction ', 'sec_number': '1'...
# 12  {'section': 'Introduction', 'sec_number': '-1'...
# 13  {'section': 'Introduction', 'sec_number': '1',...
# 14  {'section': 'Introduction', 'sec_number': '1',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Introduction', 'sec_number': '1',...
# 17  {'section': 'Introduction', 'sec_number': '1',...
# 18  {'section': 'Introduction', 'sec_number': '2',...
# 19  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                     3  \
# 0   {'section': '', 'sec_number': '-1', 'sec_type'...
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3   {'section': 'Supplemental material', 'sec_numb...
# 4   {'section': 'Introduction', 'sec_number': '1',...
# 5   {'section': 'Introduction', 'sec_number': '1',...
# 6   {'section': 'Introduction', 'sec_number': '1',...
# 7   {'section': 'Introduction', 'sec_number': '1',...
# 8   {'section': 'Introduction', 'sec_number': '1',...
# 9   {'section': 'Review of the Azimuthal Fourier d...
# 10  {'section': 'Introduction', 'sec_number': '1',...
# 11  {'section': 'Introduction ', 'sec_number': '1'...
# 12  {'section': 'Introduction', 'sec_number': '-1'...
# 13  {'section': 'Introduction', 'sec_number': '1',...
# 14  {'section': 'Introduction', 'sec_number': '1',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Introduction', 'sec_number': '1',...
# 17  {'section': 'Introduction', 'sec_number': '1',...
# 18  {'section': 'A main sequence for type-1 (unobs...
# 19  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                     4  \
# 0   {'section': '', 'sec_number': '-1', 'sec_type'...
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3   {'section': 'Supplemental material', 'sec_numb...
# 4   {'section': 'Introduction', 'sec_number': '1',...
# 5   {'section': 'Introduction', 'sec_number': '1',...
# 6   {'section': 'Introduction', 'sec_number': '1',...
# 7   {'section': 'Introduction', 'sec_number': '1',...
# 8   {'section': 'Introduction', 'sec_number': '1',...
# 9   {'section': 'Review of the Azimuthal Fourier d...
# 10  {'section': 'Introduction', 'sec_number': '1',...
# 11  {'section': 'Introduction ', 'sec_number': '1'...
# 12  {'section': 'Introduction', 'sec_number': '-1'...
# 13  {'section': 'Introduction', 'sec_number': '1',...
# 14  {'section': 'Introduction', 'sec_number': '1',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Introduction', 'sec_number': '1',...
# 17  {'section': 'Introduction', 'sec_number': '1',...
# 18  {'section': 'A main sequence for type-1 (unobs...
# 19  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                     5  \
# 0   {'section': '', 'sec_number': '-1', 'sec_type'...
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3   {'section': 'Supplemental material', 'sec_numb...
# 4   {'section': 'Introduction', 'sec_number': '1',...
# 5   {'section': 'Introduction', 'sec_number': '1',...
# 6   {'section': 'Ethereum', 'sec_number': '1', 'se...
# 7   {'section': 'Introduction', 'sec_number': '1',...
# 8   {'section': 'Introduction', 'sec_number': '1',...
# 9   {'section': 'Review of the Azimuthal Fourier d...
# 10  {'section': 'Introduction', 'sec_number': '1',...
# 11  {'section': 'Introduction ', 'sec_number': '1'...
# 12  {'section': 'Introduction', 'sec_number': '-1'...
# 13  {'section': 'Introduction', 'sec_number': '1',...
# 14  {'section': 'Introduction', 'sec_number': '1',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Weak version: prediction region c...
# 17  {'section': 'Preliminaries', 'sec_number': '2'...
# 18  {'section': 'A main sequence for type-1 (unobs...
# 19  {'section': 'Introduction', 'sec_number': '1',...
#
#                                                     6  \
# 0   {'section': '', 'sec_number': '-1', 'sec_type'...
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3   {'section': 'Supplemental material', 'sec_numb...
# 4   {'section': 'Introduction', 'sec_number': '1',...
# 5   {'section': 'Introduction', 'sec_number': '1',...
# 6   {'section': 'Ethereum', 'sec_number': '1', 'se...
# 7   {'section': 'Introduction', 'sec_number': '1',...
# 8   {'section': 'Introduction', 'sec_number': '1',...
# 9   {'section': 'Review of the Azimuthal Fourier d...
# 10  {'section': 'Nonlocal Euler-Bernoulli Beam Mod...
# 11  {'section': 'Causal structure of unitary trans...
# 12  {'section': 'Introduction', 'sec_number': '-1'...
# 13  {'section': 'Introduction', 'sec_number': '1',...
# 14  {'section': 'Introduction', 'sec_number': '1',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Weak version: prediction region c...
# 17  {'section': 'Preliminaries', 'sec_number': '2'...
# 18  {'section': 'A main sequence for type-1 (unobs...
# 19  {'section': 'From Standard to Extreme Algorith...
#
#                                                     7  \
# 0   {'section': '', 'sec_number': '-1', 'sec_type'...
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3   {'section': 'Supplemental material', 'sec_numb...
# 4   {'section': 'Introduction', 'sec_number': '1',...
# 5   {'section': 'Introduction', 'sec_number': '1',...
# 6   {'section': 'Ethereum', 'sec_number': '1', 'se...
# 7   {'section': 'Introduction', 'sec_number': '1',...
# 8   {'section': 'Introduction', 'sec_number': '1',...
# 9   {'section': 'Experimental laser focal spot dat...
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Causal structure of unitary trans...
# 12  {'section': 'Introduction', 'sec_number': '-1'...
# 13  {'section': 'Introduction', 'sec_number': '1',...
# 14  {'section': 'Introduction', 'sec_number': '1',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Weak version: prediction region c...
# 17  {'section': 'Preliminaries', 'sec_number': '2'...
# 18  {'section': 'A main sequence for type-1 (unobs...
# 19  {'section': 'From Standard to Extreme Algorith...
#
#                                                     8  \
# 0   {'section': '', 'sec_number': '-1', 'sec_type'...
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'INTRODUCTION', 'sec_number': '1',...
# 3   {'section': 'Supplemental material', 'sec_numb...
# 4   {'section': 'Introduction', 'sec_number': '1',...
# 5   {'section': 'Introduction', 'sec_number': '1',...
# 6   {'section': 'Solidity', 'sec_number': '2', 'se...
# 7   {'section': 'Introduction', 'sec_number': '1',...
# 8   {'section': 'Introduction', 'sec_number': '1',...
# 9   {'section': 'Experimental laser focal spot dat...
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Causal structure of unitary trans...
# 12  {'section': 'Results', 'sec_number': '-1', 'se...
# 13  {'section': 'Introduction', 'sec_number': '1',...
# 14  {'section': 'Introduction', 'sec_number': '1',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Weak version: prediction region c...
# 17  {'section': 'Preliminaries', 'sec_number': '2'...
# 18  {'section': 'The definition of spectral types'...
# 19  {'section': 'From Standard to Extreme Algorith...
#
#                                                     9  \
# 0   {'section': '', 'sec_number': '-1', 'sec_type'...
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'RELATED WORK', 'sec_number': '2',...
# 3   {'section': 'Supplemental material', 'sec_numb...
# 4   {'section': 'Introduction', 'sec_number': '1',...
# 5   {'section': 'Introduction', 'sec_number': '1',...
# 6   {'section': 'Contracts.', 'sec_number': '1', '...
# 7   {'section': 'Introduction', 'sec_number': '1',...
# 8   {'section': 'Our contributions', 'sec_number':...
# 9   {'section': 'Experimental laser focal spot dat...
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Causal structure of unitary trans...
# 12  {'section': 'A mixture model defines the struc...
# 13  {'section': 'Introduction', 'sec_number': '1',...
# 14  {'section': 'Introduction', 'sec_number': '1',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Weak version: prediction region c...
# 17  {'section': 'Preliminaries', 'sec_number': '2'...
# 18  {'section': 'Population A and NLSy1s', 'sec_nu...
# 19  {'section': 'From Standard to Extreme Algorith...
#
#                                                    10  \
# 0   {'section': '', 'sec_number': '-1', 'sec_type'...
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'RELATED WORK', 'sec_number': '2',...
# 3                                                None
# 4   {'section': 'Related Work', 'sec_number': '2',...
# 5   {'section': 'Introduction', 'sec_number': '1',...
# 6   {'section': 'Contracts.', 'sec_number': '1', '...
# 7   {'section': 'Graphs as non-Euclidean descripto...
# 8   {'section': 'Our contributions', 'sec_number':...
# 9   {'section': 'Experimental laser focal spot dat...
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Causal structure of unitary trans...
# 12  {'section': 'Nonlinear global dynamical models...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Related Work', 'sec_number': '2',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Weak version: prediction region c...
# 17  {'section': 'Preliminaries', 'sec_number': '2'...
# 18  {'section': 'Population A and NLSy1s', 'sec_nu...
# 19  {'section': 'From Standard to Extreme Algorith...
#
#                                                    11  \
# 0   {'section': '', 'sec_number': '-1', 'sec_type'...
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'RELATED WORK', 'sec_number': '2',...
# 3                                                None
# 4   {'section': 'Related Work', 'sec_number': '2',...
# 5   {'section': 'Introduction', 'sec_number': '1',...
# 6   {'section': 'Types.', 'sec_number': '2', 'sec_...
# 7   {'section': 'Graph theory terminologies and de...
# 8   {'section': 'Our contributions', 'sec_number':...
# 9   {'section': 'Conclusion', 'sec_number': '4', '...
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Causal structure of unitary trans...
# 12  {'section': 'Nonlinear global dynamical models...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Related Work', 'sec_number': '2',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Weak version: prediction region c...
# 17  {'section': 'Preliminaries', 'sec_number': '2'...
# 18  {'section': 'Population A and NLSy1s', 'sec_nu...
# 19  {'section': 'From Standard to Extreme Algorith...
#
#                                                    12  \
# 0                                                None
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'RELATED WORK', 'sec_number': '2',...
# 3                                                None
# 4   {'section': None, 'sec_number': '2.1', 'sec_ty...
# 5   {'section': 'Introduction', 'sec_number': '1',...
# 6   {'section': 'Types.', 'sec_number': '2', 'sec_...
# 7   {'section': 'Graph theory terminologies and de...
# 8   {'section': 'Our contributions', 'sec_number':...
# 9   {'section': 'Conclusion', 'sec_number': '4', '...
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Causal structure of unitary trans...
# 12  {'section': 'Nonlinear global dynamical models...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Related Work', 'sec_number': '2',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Strong version: beyond prediction...
# 17  {'section': 'Closed-loop frequency response of...
# 18  {'section': 'Population A and NLSy1s', 'sec_nu...
# 19  {'section': 'Exploiting Instance Features', 's...
#
#                                                    13  \
# 0                                                None
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'RELATED WORK', 'sec_number': '2',...
# 3                                                None
# 4   {'section': None, 'sec_number': '2.1', 'sec_ty...
# 5   {'section': 'Introduction', 'sec_number': '1',...
# 6   {'section': 'Data locations for reference type...
# 7   {'section': 'Graph theory terminologies and de...
# 8   {'section': 'Our contributions', 'sec_number':...
# 9                                                None
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Causal structure of unitary trans...
# 12  {'section': 'Nonlinear global dynamical models...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Related Work', 'sec_number': '2',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Strong version: beyond prediction...
# 17  {'section': 'Closed-loop frequency response of...
# 18  {'section': 'Population A and NLSy1s', 'sec_nu...
# 19  {'section': 'Regression', 'sec_number': '1', '...
#
#                                                    14  \
# 0                                                None
# 1   {'section': '', 'sec_number': '-1', 'sec_type'...
# 2   {'section': 'RELATED WORK', 'sec_number': '2',...
# 3                                                None
# 4   {'section': None, 'sec_number': '2.1', 'sec_ty...
# 5   {'section': 'Robotic platform', 'sec_number': ...
# 6   {'section': 'Data locations for reference type...
# 7   {'section': 'Graph theory terminologies and de...
# 8   {'section': 'Preliminaries', 'sec_number': '2'...
# 9                                                None
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Causal structure of unitary trans...
# 12  {'section': 'Nonlinear global dynamical models...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Related Work', 'sec_number': '2',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Strong version: beyond prediction...
# 17  {'section': 'Closed-loop frequency response of...
# 18  {'section': 'Population A and NLSy1s', 'sec_nu...
# 19  {'section': 'Regression', 'sec_number': '1', '...
#
#                                                    15  \
# 0                                                None
# 1                                                None
# 2   {'section': 'RELATED WORK', 'sec_number': '2',...
# 3                                                None
# 4   {'section': None, 'sec_number': '2.1', 'sec_ty...
# 5   {'section': 'Robotic platform', 'sec_number': ...
# 6   {'section': 'Data locations for reference type...
# 7   {'section': 'Graph theory terminologies and de...
# 8   {'section': 'Preliminaries', 'sec_number': '2'...
# 9                                                None
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Causal structure of unitary trans...
# 12  {'section': 'Nonlinear global dynamical models...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Related Work', 'sec_number': '2',...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Strong version: beyond prediction...
# 17  {'section': 'Closed-loop frequency response of...
# 18  {'section': 'Population A and NLSy1s', 'sec_nu...
# 19  {'section': 'Ranking', 'sec_number': '2', 'sec...
#
#                                                    16  \
# 0                                                None
# 1                                                None
# 2   {'section': 'RELATED WORK', 'sec_number': '2',...
# 3                                                None
# 4   {'section': None, 'sec_number': '2.1.1', 'sec_...
# 5   {'section': 'Robot simulator', 'sec_number': '...
# 6   {'section': 'Functions.', 'sec_number': '4', '...
# 7   {'section': 'Graph theory terminologies and de...
# 8   {'section': 'Preliminaries', 'sec_number': '2'...
# 9                                                None
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Causal structure of unitary trans...
# 12  {'section': 'Changes to a single parameter rep...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Citation data collection', 'sec_n...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Strong version: beyond prediction...
# 17  {'section': 'Closed-loop frequency response of...
# 18  {'section': 'Population A and NLSy1s', 'sec_nu...
# 19  {'section': 'Ranking', 'sec_number': '2', 'sec...
#
#                                                    17  \
# 0                                                None
# 1                                                None
# 2   {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                                None
# 4   {'section': None, 'sec_number': '2.1.2', 'sec_...
# 5   {'section': 'Robot simulator', 'sec_number': '...
# 6   {'section': 'Functions.', 'sec_number': '4', '...
# 7   {'section': 'Graph theory terminologies and de...
# 8   {'section': 'Preliminaries', 'sec_number': '2'...
# 9                                                None
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Causal structure of unitary trans...
# 12  {'section': 'Changes to a single parameter rep...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Background: Citations in Wikipedi...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Strong version: beyond prediction...
# 17  {'section': 'Stability and Convergence', 'sec_...
# 18  {'section': 'Extreme Population A: Selection a...
# 19  {'section': 'Ranking', 'sec_number': '2', 'sec...
#
#                                                    18  \
# 0                                                None
# 1                                                None
# 2   {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                                None
# 4   {'section': None, 'sec_number': '2.1.2', 'sec_...
# 5   {'section': 'Learning architecture', 'sec_numb...
# 6   {'section': 'Statements and expressions.', 'se...
# 7   {'section': 'Graph theory terminologies and de...
# 8   {'section': 'Preliminaries', 'sec_number': '2'...
# 9                                                None
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Causal structure of unitary trans...
# 12  {'section': 'Changes to a single parameter rep...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Background: Citations in Wikipedi...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Strong version: beyond prediction...
# 17  {'section': 'Stability and Convergence', 'sec_...
# 18  {'section': 'Extreme Population A: Selection a...
# 19  {'section': 'Ranking', 'sec_number': '2', 'sec...
#
#                                                    19  \
# 0                                                None
# 1                                                None
# 2   {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                                None
# 4   {'section': ' ', 'sec_number': '2.2', 'sec_typ...
# 5   {'section': 'Learning architecture', 'sec_numb...
# 6   {'section': 'Statements and expressions.', 'se...
# 7   {'section': 'Graph theory terminologies and de...
# 8   {'section': 'Preliminaries', 'sec_number': '2'...
# 9                                                None
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Causal structure of unitary trans...
# 12  {'section': 'Changes to a single parameter rep...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Background: Citations in Wikipedi...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Strong version: beyond prediction...
# 17  {'section': 'Stability and Convergence', 'sec_...
# 18  {'section': 'Extreme Population A: Selection a...
# 19  {'section': 'Ranking', 'sec_number': '2', 'sec...
#
#                                                    20  \
# 0                                                None
# 1                                                None
# 2   {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                                None
# 4   {'section': ' ', 'sec_number': '2.2', 'sec_typ...
# 5   {'section': 'Learning architecture', 'sec_numb...
# 6   {'section': 'Statements and expressions.', 'se...
# 7   {'section': 'Graph theory terminologies and de...
# 8   {'section': 'Preliminaries', 'sec_number': '2'...
# 9                                                None
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Decompositions using circuit diag...
# 12  {'section': 'Changes to a single parameter rep...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Background: Citations in Wikipedi...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Strong version: beyond prediction...
# 17  {'section': 'Stability and Convergence', 'sec_...
# 18  {'section': 'Extreme Population A: Selection a...
# 19  {'section': 'Ranking', 'sec_number': '2', 'sec...
#
#                                                    21  \
# 0                                                None
# 1                                                None
# 2   {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                                None
# 4   {'section': None, 'sec_number': '3.1', 'sec_ty...
# 5   {'section': 'Forward and inverse models', 'sec...
# 6   {'section': 'SMT-Based Programs', 'sec_number'...
# 7   {'section': 'Graph theory terminologies and de...
# 8   {'section': 'Preliminaries', 'sec_number': '2'...
# 9                                                None
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Decompositions using circuit diag...
# 12  {'section': 'Robustness of results to paramete...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Logging citation and page load ev...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Strong version: beyond prediction...
# 17  {'section': 'Stability and Convergence', 'sec_...
# 18  {'section': 'Extreme Population A: Selection a...
# 19  {'section': 'Collaborative Filtering', 'sec_nu...
#
#                                                    22  \
# 0                                                None
# 1                                                None
# 2   {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                                None
# 4   {'section': None, 'sec_number': '3.2', 'sec_ty...
# 5   {'section': 'Forward and inverse models', 'sec...
# 6   {'section': 'SMT-Based Programs', 'sec_number'...
# 7   {'section': 'Graph theory terminologies and de...
# 8   {'section': 'Preliminaries', 'sec_number': '2'...
# 9                                                None
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Decompositions using circuit diag...
# 12  {'section': 'Nonlinear model recreates dynamic...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Logging citation and page load ev...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Strong version: beyond prediction...
# 17  {'section': 'Stability and Convergence', 'sec_...
# 18  {'section': 'Extreme Population A: Selection a...
# 19  {'section': 'Collaborative Filtering', 'sec_nu...
#
#                                                    23  \
# 0                                                None
# 1                                                None
# 2   {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                                None
# 4   {'section': None, 'sec_number': '3.2', 'sec_ty...
# 5   {'section': 'Forward and inverse models', 'sec...
# 6   {'section': 'SMT-Based Programs', 'sec_number'...
# 7   {'section': 'Graph theory terminologies and de...
# 8   {'section': 'Preliminaries', 'sec_number': '2'...
# 9                                                None
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Decompositions using circuit diag...
# 12  {'section': 'Nonlinear model recreates dynamic...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Logging citation and page load ev...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Strong version: beyond prediction...
# 17  {'section': 'Stability and Convergence', 'sec_...
# 18  {'section': 'Extreme Population A: Selection a...
# 19  {'section': 'Collaborative Filtering', 'sec_nu...
#
#                                                    24  \
# 0                                                None
# 1                                                None
# 2   {'section': 'MINHASH SKETCHES', 'sec_number': ...
# 3                                                None
# 4   {'section': None, 'sec_number': '3.2', 'sec_ty...
# 5   {'section': 'Forward and inverse models', 'sec...
# 6   {'section': 'SMT-Based Programs', 'sec_number'...
# 7   {'section': 'Graph theory terminologies and de...
# 8   {'section': 'Preliminaries', 'sec_number': '2'...
# 9                                                None
# 10  {'section': 'Nonlocal Continuum Formulation', ...
# 11  {'section': 'Decompositions using circuit diag...
# 12  {'section': 'Discussion', 'sec_number': '-1', ...
# 13  {'section': 'Preliminaries', 'sec_number': '2'...
# 14  {'section': 'Logging citation and page load ev...
# 15  {'section': '', 'sec_number': '-1', 'sec_type'...
# 16  {'section': 'Strong version: beyond prediction...
# 17  {'section': 'Stability and Convergence', 'sec_...
# 18  {'section': 'Extreme Population A: Selection a...
# 19  {'section': 'Collaborative Filtering', 'sec_nu...
#
#                                                    25  \
# 0                                                None
# 1                                                None
# 2   {'section': 'METHOD', 'sec_number': '4', 'sec_...
# 3                                                None
# 4   {'section': None, 'sec_number': '3.2', 'sec_ty...
# 5   {'section': 'Goal selection and learning progr...
# 6   {'section': 'SMT-Based Programs', 'sec_number'...
# 7   {'section': 'Graph theory terminologies and de...
# ...
# 9   None  None  None  None  None  None  None  None  None  None  None  None
# 10  None  None  None  None  None  None  None  None  None  None  None  None
# 11  None  None  None  None  None  None  None  None  None  None  None  None
# 12  None  None  None  None  None  None  None  None  None  None  None  None
# 13  None  None  None  None  None  None  None  None  None  None  None  None
# 14  None  None  None  None  None  None  None  None  None  None  None  None
# 15  None  None  None  None  None  None  None  None  None  None  None  None
# 16  None  None  None  None  None  None  None  None  None  None  None  None
# 17  None  None  None  None  None  None  None  None  None  None  None  None
# 18  None  None  None  None  None  None  None  None  None  None  None  None
# 19  None  None  None  None  None  None  None  None  None  None  None  None
#
#     1063  1064  1065  1066  1067  1068  1069  1070  1071  1072  1073  1074  \
# 0   None  None  None  None  None  None  None  None  None  None  None  None
# 1   None  None  None  None  None  None  None  None  None  None  None  None
# 2   None  None  None  None  None  None  None  None  None  None  None  None
# 3   None  None  None  None  None  None  None  None  None  None  None  None
# 4   None  None  None  None  None  None  None  None  None  None  None  None
# 5   None  None  None  None  None  None  None  None  None  None  None  None
# 6   None  None  None  None  None  None  None  None  None  None  None  None
# 7   None  None  None  None  None  None  None  None  None  None  None  None
# 8   None  None  None  None  None  None  None  None  None  None  None  None
# 9   None  None  None  None  None  None  None  None  None  None  None  None
# 10  None  None  None  None  None  None  None  None  None  None  None  None
# 11  None  None  None  None  None  None  None  None  None  None  None  None
# 12  None  None  None  None  None  None  None  None  None  None  None  None
# 13  None  None  None  None  None  None  None  None  None  None  None  None
# 14  None  None  None  None  None  None  None  None  None  None  None  None
# 15  None  None  None  None  None  None  None  None  None  None  None  None
# 16  None  None  None  None  None  None  None  None  None  None  None  None
# 17  None  None  None  None  None  None  None  None  None  None  None  None
# 18  None  None  None  None  None  None  None  None  None  None  None  None
# 19  None  None  None  None  None  None  None  None  None  None  None  None
#
#     1075  1076  1077  1078  1079  1080  1081  1082  1083  1084  1085  1086  \
# 0   None  None  None  None  None  None  None  None  None  None  None  None
# 1   None  None  None  None  None  None  None  None  None  None  None  None
# 2   None  None  None  None  None  None  None  None  None  None  None  None
# 3   None  None  None  None  None  None  None  None  None  None  None  None
# 4   None  None  None  None  None  None  None  None  None  None  None  None
# 5   None  None  None  None  None  None  None  None  None  None  None  None
# 6   None  None  None  None  None  None  None  None  None  None  None  None
# 7   None  None  None  None  None  None  None  None  None  None  None  None
# 8   None  None  None  None  None  None  None  None  None  None  None  None
# 9   None  None  None  None  None  None  None  None  None  None  None  None
# 10  None  None  None  None  None  None  None  None  None  None  None  None
# 11  None  None  None  None  None  None  None  None  None  None  None  None
# 12  None  None  None  None  None  None  None  None  None  None  None  None
# 13  None  None  None  None  None  None  None  None  None  None  None  None
# 14  None  None  None  None  None  None  None  None  None  None  None  None
# 15  None  None  None  None  None  None  None  None  None  None  None  None
# 16  None  None  None  None  None  None  None  None  None  None  None  None
# 17  None  None  None  None  None  None  None  None  None  None  None  None
# 18  None  None  None  None  None  None  None  None  None  None  None  None
# 19  None  None  None  None  None  None  None  None  None  None  None  None
#
#     1087  1088  1089  1090  1091  1092  1093  1094  1095  1096  1097  1098  \
# 0   None  None  None  None  None  None  None  None  None  None  None  None
# 1   None  None  None  None  None  None  None  None  None  None  None  None
# 2   None  None  None  None  None  None  None  None  None  None  None  None
# 3   None  None  None  None  None  None  None  None  None  None  None  None
# 4   None  None  None  None  None  None  None  None  None  None  None  None
# 5   None  None  None  None  None  None  None  None  None  None  None  None
# 6   None  None  None  None  None  None  None  None  None  None  None  None
# 7   None  None  None  None  None  None  None  None  None  None  None  None
# 8   None  None  None  None  None  None  None  None  None  None  None  None
# 9   None  None  None  None  None  None  None  None  None  None  None  None
# 10  None  None  None  None  None  None  None  None  None  None  None  None
# 11  None  None  None  None  None  None  None  None  None  None  None  None
# 12  None  None  None  None  None  None  None  None  None  None  None  None
# 13  None  None  None  None  None  None  None  None  None  None  None  None
# 14  None  None  None  None  None  None  None  None  None  None  None  None
# 15  None  None  None  None  None  None  None  None  None  None  None  None
# 16  None  None  None  None  None  None  None  None  None  None  None  None
# 17  None  None  None  None  None  None  None  None  None  None  None  None
# 18  None  None  None  None  None  None  None  None  None  None  None  None
# 19  None  None  None  None  None  None  None  None  None  None  None  None
#
#     1099  1100  1101  1102  1103  1104  1105  1106  1107  1108  1109  1110  \
# 0   None  None  None  None  None  None  None  None  None  None  None  None
# 1   None  None  None  None  None  None  None  None  None  None  None  None
# 2   None  None  None  None  None  None  None  None  None  None  None  None
# 3   None  None  None  None  None  None  None  None  None  None  None  None
# 4   None  None  None  None  None  None  None  None  None  None  None  None
# 5   None  None  None  None  None  None  None  None  None  None  None  None
# 6   None  None  None  None  None  None  None  None  None  None  None  None
# 7   None  None  None  None  None  None  None  None  None  None  None  None
# 8   None  None  None  None  None  None  None  None  None  None  None  None
# 9   None  None  None  None  None  None  None  None  None  None  None  None
# 10  None  None  None  None  None  None  None  None  None  None  None  None
# 11  None  None  None  None  None  None  None  None  None  None  None  None
# 12  None  None  None  None  None  None  None  None  None  None  None  None
# 13  None  None  None  None  None  None  None  None  None  None  None  None
# 14  None  None  None  None  None  None  None  None  None  None  None  None
# 15  None  None  None  None  None  None  None  None  None  None  None  None
# 16  None  None  None  None  None  None  None  None  None  None  None  None
# 17  None  None  None  None  None  None  None  None  None  None  None  None
# 18  None  None  None  None  None  None  None  None  None  None  None  None
# 19  None  None  None  None  None  None  None  None  None  None  None  None
#
#     1111  1112  1113  1114  1115  1116  1117  1118  1119  1120  1121  1122  \
# 0   None  None  None  None  None  None  None  None  None  None  None  None
# 1   None  None  None  None  None  None  None  None  None  None  None  None
# 2   None  None  None  None  None  None  None  None  None  None  None  None
# 3   None  None  None  None  None  None  None  None  None  None  None  None
# 4   None  None  None  None  None  None  None  None  None  None  None  None
# 5   None  None  None  None  None  None  None  None  None  None  None  None
# 6   None  None  None  None  None  None  None  None  None  None  None  None
# 7   None  None  None  None  None  None  None  None  None  None  None  None
# 8   None  None  None  None  None  None  None  None  None  None  None  None
# 9   None  None  None  None  None  None  None  None  None  None  None  None
# 10  None  None  None  None  None  None  None  None  None  None  None  None
# 11  None  None  None  None  None  None  None  None  None  None  None  None
# 12  None  None  None  None  None  None  None  None  None  None  None  None
# 13  None  None  None  None  None  None  None  None  None  None  None  None
# 14  None  None  None  None  None  None  None  None  None  None  None  None
# 15  None  None  None  None  None  None  None  None  None  None  None  None
# 16  None  None  None  None  None  None  None  None  None  None  None  None
# 17  None  None  None  None  None  None  None  None  None  None  None  None
# 18  None  None  None  None  None  None  None  None  None  None  None  None
# 19  None  None  None  None  None  None  None  None  None  None  None  None
#
#     1123  1124  1125  1126  1127  1128  1129  1130  1131  1132  1133  1134  \
# 0   None  None  None  None  None  None  None  None  None  None  None  None
# 1   None  None  None  None  None  None  None  None  None  None  None  None
# 2   None  None  None  None  None  None  None  None  None  None  None  None
# 3   None  None  None  None  None  None  None  None  None  None  None  None
# 4   None  None  None  None  None  None  None  None  None  None  None  None
# 5   None  None  None  None  None  None  None  None  None  None  None  None
# 6   None  None  None  None  None  None  None  None  None  None  None  None
# 7   None  None  None  None  None  None  None  None  None  None  None  None
# 8   None  None  None  None  None  None  None  None  None  None  None  None
# 9   None  None  None  None  None  None  None  None  None  None  None  None
# 10  None  None  None  None  None  None  None  None  None  None  None  None
# 11  None  None  None  None  None  None  None  None  None  None  None  None
# 12  None  None  None  None  None  None  None  None  None  None  None  None
# 13  None  None  None  None  None  None  None  None  None  None  None  None
# 14  None  None  None  None  None  None  None  None  None  None  None  None
# 15  None  None  None  None  None  None  None  None  None  None  None  None
# 16  None  None  None  None  None  None  None  None  None  None  None  None
# 17  None  None  None  None  None  None  None  None  None  None  None  None
# 18  None  None  None  None  None  None  None  None  None  None  None  None
# 19  None  None  None  None  None  None  None  None  None  None  None  None
#
#     1135  1136  1137  1138  1139  1140  1141  1142  1143  1144  1145  1146  \
# 0   None  None  None  None  None  None  None  None  None  None  None  None
# 1   None  None  None  None  None  None  None  None  None  None  None  None
# 2   None  None  None  None  None  None  None  None  None  None  None  None
# 3   None  None  None  None  None  None  None  None  None  None  None  None
# 4   None  None  None  None  None  None  None  None  None  None  None  None
# 5   None  None  None  None  None  None  None  None  None  None  None  None
# 6   None  None  None  None  None  None  None  None  None  None  None  None
# 7   None  None  None  None  None  None  None  None  None  None  None  None
# 8   None  None  None  None  None  None  None  None  None  None  None  None
# 9   None  None  None  None  None  None  None  None  None  None  None  None
# 10  None  None  None  None  None  None  None  None  None  None  None  None
# 11  None  None  None  None  None  None  None  None  None  None  None  None
# 12  None  None  None  None  None  None  None  None  None  None  None  None
# 13  None  None  None  None  None  None  None  None  None  None  None  None
# 14  None  None  None  None  None  None  None  None  None  None  None  None
# 15  None  None  None  None  None  None  None  None  None  None  None  None
# 16  None  None  None  None  None  None  None  None  None  None  None  None
# 17  None  None  None  None  None  None  None  None  None  None  None  None
# 18  None  None  None  None  None  None  None  None  None  None  None  None
# 19  None  None  None  None  None  None  None  None  None  None  None  None
#
#     1147  1148  1149  1150  1151  1152  1153  1154  1155  1156  1157  1158  \
# 0   None  None  None  None  None  None  None  None  None  None  None  None
# 1   None  None  None  None  None  None  None  None  None  None  None  None
# 2   None  None  None  None  None  None  None  None  None  None  None  None
# 3   None  None  None  None  None  None  None  None  None  None  None  None
# 4   None  None  None  None  None  None  None  None  None  None  None  None
# 5   None  None  None  None  None  None  None  None  None  None  None  None
# 6   None  None  None  None  None  None  None  None  None  None  None  None
# 7   None  None  None  None  None  None  None  None  None  None  None  None
# 8   None  None  None  None  None  None  None  None  None  None  None  None
# 9   None  None  None  None  None  None  None  None  None  None  None  None
# 10  None  None  None  None  None  None  None  None  None  None  None  None
# 11  None  None  None  None  None  None  None  None  None  None  None  None
# 12  None  None  None  None  None  None  None  None  None  None  None  None
# 13  None  None  None  None  None  None  None  None  None  None  None  None
# 14  None  None  None  None  None  None  None  None  None  None  None  None
# 15  None  None  None  None  None  None  None  None  None  None  None  None
# 16  None  None  None  None  None  None  None  None  None  None  None  None
# 17  None  None  None  None  None  None  None  None  None  None  None  None
# 18  None  None  None  None  None  None  None  None  None  None  None  None
# 19  None  None  None  None  None  None  None  None  None  None  None  None
#
#     1159  1160  1161  1162  1163  1164  1165  1166  1167  1168  1169  1170  \
# 0   None  None  None  None  None  None  None  None  None  None  None  None
# 1   None  None  None  None  None  None  None  None  None  None  None  None
# 2   None  None  None  None  None  None  None  None  None  None  None  None
# 3   None  None  None  None  None  None  None  None  None  None  None  None
# 4   None  None  None  None  None  None  None  None  None  None  None  None
# 5   None  None  None  None  None  None  None  None  None  None  None  None
# 6   None  None  None  None  None  None  None  None  None  None  None  None
# 7   None  None  None  None  None  None  None  None  None  None  None  None
# 8   None  None  None  None  None  None  None  None  None  None  None  None
# 9   None  None  None  None  None  None  None  None  None  None  None  None
# 10  None  None  None  None  None  None  None  None  None  None  None  None
# 11  None  None  None  None  None  None  None  None  None  None  None  None
# 12  None  None  None  None  None  None  None  None  None  None  None  None
# 13  None  None  None  None  None  None  None  None  None  None  None  None
# 14  None  None  None  None  None  None  None  None  None  None  None  None
# 15  None  None  None  None  None  None  None  None  None  None  None  None
# 16  None  None  None  None  None  None  None  None  None  None  None  None
# 17  None  None  None  None  None  None  None  None  None  None  None  None
# 18  None  None  None  None  None  None  None  None  None  None  None  None
# 19  None  None  None  None  None  None  None  None  None  None  None  None
#
#     1171  1172
# 0   None  None
# 1   None  None
# 2   None  None
# 3   None  None
# 4   None  None
# 5   None  None
# 6   None  None
# 7   None  None
# 8   None  None
# 9   None  None
# 10  None  None
# 11  None  None
# 12  None  None
# 13  None  None
# 14  None  None
# 15  None  None
# 16  None  None
# 17  None  None
# 18  None  None
# 19  None  None

# %%
# df2 = df1[['paper_id','discipline','submitter','authors','title','comments','journal-ref','doi','categories','abstract','update_date','versions','authors_parsed','section','text','0']]
# df2.head()

# %%
df2 = df1[['paper_id','discipline','submitter','authors','title','comments','journal-ref','doi','categories','abstract','update_date','versions','authors_parsed','section','text']]
df2.head()
# Out:
#      paper_id  discipline         submitter  \
# 0  2001.00542     Physics   Uro\v{s} Tkalec
# 1  2001.00552     Physics   Uro\v{s} Tkalec
# 2  2001.01128  Statistics   Ilan Ben-Bassat
# 3  2001.01237     Physics       Ligong Bian
# 4  2001.01618  Statistics  Sudipta Paul Ms.
#
#                                              authors  \
# 0  Simon \v{C}opar, \v{Z}iga Kos, Tadej Emer\v{s}...
# 1  Tadej Emer\v{s}i\v{c}, Rui Zhang, \v{Z}iga Kos...
# 2                     Ilan Ben-Bassat and Erez Rokah
# 3                            Ruiyu Zhou, Ligong Bian
# 4                  Sudipta Paul and Subhankar Mishra
#
#                                                title  \
# 0  Microfluidic control over topological states i...
# 1        Sculpting stable structures in pure liquids
# 2  Locality-Sensitive Hashing for Efficient Web A...
# 3  Gravitational wave and electroweak baryogenesi...
# 4  ARA : Aggregated RAPPOR and Analysis for Centr...
#
#                                     comments  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3  7 pages, 5 figures, PLB published version
# 4                                       None
#
#                                          journal-ref  \
# 0          Nature Communications, vol. 11, 59 (2020)
# 1          Science Advances, vol. 5, eaav4283 (2019)
# 2  In Proceedings of the 5th International Confer...
# 3                      Phys.Lett.B 829 (2022) 137105
# 4                       SN COMPUT. SCI. (2020) 1: 22
#
#                               doi           categories  \
# 0      10.1038/s41467-019-13789-9        cond-mat.soft
# 1          10.1126/sciadv.aav4283        cond-mat.soft
# 2        10.5220/0007255301930204  cs.CR cs.LG stat.ML
# 3  10.1016/j.physletb.2022.137105   hep-ph astro-ph.CO
# 4       10.1007/s42979-019-0023-y  cs.CR cs.LG stat.ML
#
#                                             abstract  \
# 0  {'section': 'Abstract', 'text': '  Compared to...
# 1  {'section': 'Abstract', 'text': '  Pure liquid...
# 2  {'section': 'Abstract', 'text': '  Web applica...
# 3  {'section': 'Abstract', 'text': '  We study st...
# 4  {'section': 'Abstract', 'text': '  Differentia...
#
#                                             abstract update_date  \
# 0    Compared to isotropic liquids, orientational...  2020-01-03
# 1    Pure liquids in thermodynamic equilibrium ar...  2020-01-03
# 2    Web application security has become a major ...  2020-01-07
# 3    We study stochastic gravitational wave produ...  2022-04-19
# 4    Differential privacy(DP) has now become a st...  2020-01-07
#
#                                             versions  \
# 0  [{'version': 'v1', 'created': 'Thu, 2 Jan 2020...
# 1  [{'version': 'v1', 'created': 'Thu, 2 Jan 2020...
# 2  [{'version': 'v1', 'created': 'Sat, 4 Jan 2020...
# 3  [{'version': 'v1', 'created': 'Sun, 5 Jan 2020...
# 4  [{'version': 'v1', 'created': 'Mon, 6 Jan 2020...
#
#                                       authors_parsed   section  \
# 0  [[Čopar, Simon, ], [Kos, Žiga, ], [Emeršič, Ta...  Abstract
# 1  [[Emeršič, Tadej, ], [Zhang, Rui, ], [Kos, Žig...  Abstract
# 2            [[Ben-Bassat, Ilan, ], [Rokah, Erez, ]]  Abstract
# 3                [[Zhou, Ruiyu, ], [Bian, Ligong, ]]  Abstract
# 4         [[Paul, Sudipta, ], [Mishra, Subhankar, ]]  Abstract
#
#                                                 text
# 0    Compared to isotropic liquids, orientational...
# 1    Pure liquids in thermodynamic equilibrium ar...
# 2    Web application security has become a major ...
# 3    We study stochastic gravitational wave produ...
# 4    Differential privacy(DP) has now become a st...

# %%
csv_file_path = 'dataset.csv'

# Convert the DataFrame to a CSV file
df2.to_csv(csv_file_path, index=False)

# %%
df1.isnull().sum()
# Out:
# paper_id        0
# discipline      0
# abstract        0
# body_text       0
# submitter       0
#              ...
# 1168          794
# 1169          794
# 1170          794
# 1171          794
# 1172          794
# Length: 1194, dtype: int64

# %%
df3  = pd.read_csv('/kaggle/working/dataset.csv')
df3.head()
# Out:
#      paper_id  discipline         submitter  \
# 0  2001.00542     Physics   Uro\v{s} Tkalec
# 1  2001.00552     Physics   Uro\v{s} Tkalec
# 2  2001.01128  Statistics   Ilan Ben-Bassat
# 3  2001.01237     Physics       Ligong Bian
# 4  2001.01618  Statistics  Sudipta Paul Ms.
#
#                                              authors  \
# 0  Simon \v{C}opar, \v{Z}iga Kos, Tadej Emer\v{s}...
# 1  Tadej Emer\v{s}i\v{c}, Rui Zhang, \v{Z}iga Kos...
# 2                     Ilan Ben-Bassat and Erez Rokah
# 3                            Ruiyu Zhou, Ligong Bian
# 4                  Sudipta Paul and Subhankar Mishra
#
#                                                title  \
# 0  Microfluidic control over topological states i...
# 1        Sculpting stable structures in pure liquids
# 2  Locality-Sensitive Hashing for Efficient Web A...
# 3  Gravitational wave and electroweak baryogenesi...
# 4  ARA : Aggregated RAPPOR and Analysis for Centr...
#
#                                     comments  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3  7 pages, 5 figures, PLB published version
# 4                                        NaN
#
#                                          journal-ref  \
# 0          Nature Communications, vol. 11, 59 (2020)
# 1          Science Advances, vol. 5, eaav4283 (2019)
# 2  In Proceedings of the 5th International Confer...
# 3                      Phys.Lett.B 829 (2022) 137105
# 4                       SN COMPUT. SCI. (2020) 1: 22
#
#                               doi           categories  \
# 0      10.1038/s41467-019-13789-9        cond-mat.soft
# 1          10.1126/sciadv.aav4283        cond-mat.soft
# 2        10.5220/0007255301930204  cs.CR cs.LG stat.ML
# 3  10.1016/j.physletb.2022.137105   hep-ph astro-ph.CO
# 4       10.1007/s42979-019-0023-y  cs.CR cs.LG stat.ML
#
#                                             abstract  \
# 0  {'section': 'Abstract', 'text': '  Compared to...
# 1  {'section': 'Abstract', 'text': '  Pure liquid...
# 2  {'section': 'Abstract', 'text': '  Web applica...
# 3  {'section': 'Abstract', 'text': '  We study st...
# 4  {'section': 'Abstract', 'text': '  Differentia...
#
#                                           abstract.1 update_date  \
# 0    Compared to isotropic liquids, orientational...  2020-01-03
# 1    Pure liquids in thermodynamic equilibrium ar...  2020-01-03
# 2    Web application security has become a major ...  2020-01-07
# 3    We study stochastic gravitational wave produ...  2022-04-19
# 4    Differential privacy(DP) has now become a st...  2020-01-07
#
#                                             versions  \
# 0  [{'version': 'v1', 'created': 'Thu, 2 Jan 2020...
# 1  [{'version': 'v1', 'created': 'Thu, 2 Jan 2020...
# 2  [{'version': 'v1', 'created': 'Sat, 4 Jan 2020...
# 3  [{'version': 'v1', 'created': 'Sun, 5 Jan 2020...
# 4  [{'version': 'v1', 'created': 'Mon, 6 Jan 2020...
#
#                                       authors_parsed   section  \
# 0  [['Čopar', 'Simon', ''], ['Kos', 'Žiga', ''], ...  Abstract
# 1  [['Emeršič', 'Tadej', ''], ['Zhang', 'Rui', ''...  Abstract
# 2  [['Ben-Bassat', 'Ilan', ''], ['Rokah', 'Erez',...  Abstract
# 3    [['Zhou', 'Ruiyu', ''], ['Bian', 'Ligong', '']]  Abstract
# 4  [['Paul', 'Sudipta', ''], ['Mishra', 'Subhanka...  Abstract
#
#                                                 text
# 0    Compared to isotropic liquids, orientational...
# 1    Pure liquids in thermodynamic equilibrium ar...
# 2    Web application security has become a major ...
# 3    We study stochastic gravitational wave produ...
# 4    Differential privacy(DP) has now become a st...
